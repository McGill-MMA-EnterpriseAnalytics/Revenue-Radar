# %%
#Import necessary libraries
import os
import pandas as pd
import json

# %% [markdown]
# ### Ignore These

# %%
#Set the working directory 
#os.chdir("/Users/Abdul/Desktop/MMA/Enterprise Data Science/Revenue-Radar/Data")

# %%
#Import dataset(s)
#train_revenue = pd.read_csv("train.csv")
#test_revenue = pd.read_csv("test.csv")

# %%
dict_columns = ['geoNetwork', 'device', 'totals', 'trafficSource']

# For each such column, convert the string representation of dictionary to actual dictionary
# then normalize and concatenate with the original DataFrame
for column in dict_columns:
    # Convert the stringified dictionary to actual dictionary
    train_revenue[column] = train_revenue[column].apply(json.loads)
    
    # Flatten the dictionary and convert to a DataFrame
    column_df = pd.json_normalize(train_revenue[column])
    
    # Concatenate the new DataFrame to the original DataFrame
    train_revenue = pd.concat([train_revenue, column_df], axis=1)

    # Drop the original column that contained the stringified dictionary
    train_revenue.drop(column, axis=1, inplace=True)

for column in dict_columns:
    # Convert the stringified dictionary to actual dictionary
    test_revenue[column] = test_revenue[column].apply(json.loads)
    
    # Flatten the dictionary and convert to a DataFrame
    column_df = pd.json_normalize(test_revenue[column])
    
    # Concatenate the new DataFrame to the original DataFrame
    test_revenue = pd.concat([test_revenue, column_df], axis=1)

    # Drop the original column that contained the stringified dictionary
    test_revenue.drop(column, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yvankammelu/Documents/GitHub/Revenue-Radar/DeepClean_and_EDA.ipynb Cell 5 line 7
#       <a href='vscode-notebook-cell:/Users/yvankammelu/Documents/GitHub/Revenue-Radar/DeepClean_and_EDA.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> # For each such column, convert the string representation of dictionary to actual dictionary
#       <a href='vscode-notebook-cell:/Users/yvankammelu/Documents/GitHub/Revenue-Radar/DeepClean_and_EDA.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> # then normalize and concatenate with the original DataFrame
#       <a href='vscode-notebook-cell:/Users/yvankammelu/Documents/GitHub/Revenue-Radar/DeepClean_and_EDA.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> for column in dict_columns:
#       <a href='vscode-notebook-cell:/Users/yvankammelu/Documents/GitHub/Revenue-Radar/DeepClean_and_EDA.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>     # Convert the stringified dictionary to actual dictionary
# ----> <a href='vscode-notebook-cell:/Users/yvankammelu/Documents/GitHub/Revenue-Radar/DeepClean_and_EDA.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     train_revenue[column] = train_revenue[column].apply(json.loads)
#       <a href='vscode-notebook-cell:/Users/yvankammelu/Documents/GitHub/Revenue-Radar/DeepClean_and_EDA.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a>     # Flatten the dictionary and convert to a DataFrame
#      <a href='vscode-notebook-cell:/Users/yvankammelu/Documents/GitHub/Revenue-Radar/DeepClean_and_EDA.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a>     column_df = pd.json_normalize(train_revenue[column])
#
# NameError: name 'train_revenue' is not defined

# %%
#Viewing first 5 rows of the training dataset
train_revenue.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime continent     subContinent  ...  \
# 0            1      1472830385      Asia     Western Asia  ...
# 1            1      1472880147   Oceania      Australasia  ...
# 2            1      1472865386    Europe  Southern Europe  ...
# 3            1      1472881213      Asia   Southeast Asia  ...
# 4            2      1472822600    Europe  Northern Europe  ...
#
#   adwordsClickInfo.criteriaParameters isTrueDirect referralPath  \
# 0       not available in demo dataset          NaN          NaN
# 1       not available in demo dataset          NaN          NaN
# 2       not available in demo dataset          NaN          NaN
# 3       not available in demo dataset          NaN          NaN
# 4       not available in demo dataset         True          NaN
#
#   adwordsClickInfo.page adwordsClickInfo.slot adwordsClickInfo.gclId  \
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
#   adwordsClickInfo.adNetworkType adwordsClickInfo.isVideoAd adContent  \
# 0                            NaN                        NaN       NaN
# 1                            NaN                        NaN       NaN
# 2                            NaN                        NaN       NaN
# 3                            NaN                        NaN       NaN
# 4                            NaN                        NaN       NaN
#
#   campaignCode
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 55 columns]

# %%
#Viewing first 5 rows of the testing dataset
test_revenue.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20171016  6167871330617112363
# 1  Organic Search  20171016  0643697640977915618
# 2  Organic Search  20171016  6059383810968229466
# 3  Organic Search  20171016  2376720078563423631
# 4  Organic Search  20171016  2314544520795440038
#
#                         sessionId  socialEngagementType     visitId  \
# 0  6167871330617112363_1508151024  Not Socially Engaged  1508151024
# 1  0643697640977915618_1508175522  Not Socially Engaged  1508175522
# 2  6059383810968229466_1508143220  Not Socially Engaged  1508143220
# 3  2376720078563423631_1508193530  Not Socially Engaged  1508193530
# 4  2314544520795440038_1508217442  Not Socially Engaged  1508217442
#
#    visitNumber  visitStartTime continent      subContinent  ...  \
# 0            2      1508151024      Asia    Southeast Asia  ...
# 1            1      1508175522    Europe   Southern Europe  ...
# 2            1      1508143220    Europe    Western Europe  ...
# 3            1      1508193530  Americas  Northern America  ...
# 4            1      1508217442  Americas  Northern America  ...
#
#           keyword isTrueDirect adwordsClickInfo.criteriaParameters  \
# 0  (not provided)         True       not available in demo dataset
# 1  (not provided)          NaN       not available in demo dataset
# 2  (not provided)          NaN       not available in demo dataset
# 3  (not provided)          NaN       not available in demo dataset
# 4  (not provided)          NaN       not available in demo dataset
#
#   adwordsClickInfo.page adwordsClickInfo.slot adwordsClickInfo.gclId  \
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
#   adwordsClickInfo.adNetworkType adwordsClickInfo.isVideoAd referralPath  \
# 0                            NaN                        NaN          NaN
# 1                            NaN                        NaN          NaN
# 2                            NaN                        NaN          NaN
# 3                            NaN                        NaN          NaN
# 4                            NaN                        NaN          NaN
#
#   adContent
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 53 columns]

# %% [markdown]
# ### Subsetting Data For Regression Task

# %%
#importing the training set
pwd = os.getcwd()
filepath = os.path.join(pwd, "Data/debug_train_dejsonified.csv")

df_train=pd.read_csv(filepath)

print(df_train.head())
#IGNORE NOT USING TEST IN EDA Importing the test set
#df_test=pd.read_csv("/Users/Abdul/Desktop/MMA/Enterprise Data Science/Revenue-Radar/Data/test_dejsonified.csv")
# Out:
# /Users/yvankammelu/anaconda3/envs/causalml-py38/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (2,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime continent     subContinent  ...  \
# 0            1      1472830385      Asia     Western Asia  ...
# 1            1      1472880147   Oceania      Australasia  ...
# 2            1      1472865386    Europe  Southern Europe  ...
# 3            1      1472881213      Asia   Southeast Asia  ...
# 4            2      1472822600    Europe  Northern Europe  ...
#
#   adwordsClickInfo.criteriaParameters isTrueDirect referralPath  \
# 0       not available in demo dataset          NaN          NaN
# 1       not available in demo dataset          NaN          NaN
# 2       not available in demo dataset          NaN          NaN
# 3       not available in demo dataset          NaN          NaN
# 4       not available in demo dataset         True          NaN
#
#   adwordsClickInfo.page adwordsClickInfo.slot adwordsClickInfo.gclId  \
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
#   adwordsClickInfo.adNetworkType adwordsClickInfo.isVideoAd adContent  \
# 0                            NaN                        NaN       NaN
# 1                            NaN                        NaN       NaN
# 2                            NaN                        NaN       NaN
# 3                            NaN                        NaN       NaN
# 4                            NaN                        NaN       NaN
#
#   campaignCode
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 55 columns]

# %%
print('The dimensions of the training dataset are:', df_train.shape)
#print('The dimensions of the testing dataset are:', df_test.shape)
# Out:
# The dimensions of the training dataset are: (903653, 55)

# %%
# Printing all the column names for exploration and understanding the dataset
df_train.columns.to_list()
# Out:
# ['channelGrouping',
#  'date',
#  'fullVisitorId',
#  'sessionId',
#  'socialEngagementType',
#  'visitId',
#  'visitNumber',
#  'visitStartTime',
#  'continent',
#  'subContinent',
#  'country',
#  'region',
#  'metro',
#  'city',
#  'cityId',
#  'networkDomain',
#  'latitude',
#  'longitude',
#  'networkLocation',
#  'browser',
#  'browserVersion',
#  'browserSize',
#  'operatingSystem',
#  'operatingSystemVersion',
#  'isMobile',
#  'mobileDeviceBranding',
#  'mobileDeviceModel',
#  'mobileInputSelector',
#  'mobileDeviceInfo',
#  'mobileDeviceMarketingName',
#  'flashVersion',
#  'language',
#  'screenColors',
#  'screenResolution',
#  'deviceCategory',
#  'visits',
#  'hits',
#  'pageviews',
#  'bounces',
#  'newVisits',
#  'transactionRevenue',
#  'campaign',
#  'source',
#  'medium',
#  'keyword',
#  'adwordsClickInfo.criteriaParameters',
#  'isTrueDirect',
#  'referralPath',
#  'adwordsClickInfo.page',
#  'adwordsClickInfo.slot',
#  'adwordsClickInfo.gclId',
#  'adwordsClickInfo.adNetworkType',
#  'adwordsClickInfo.isVideoAd',
#  'adContent',
#  'campaignCode']

# %%
# printing all the column names for exploration and understanding the dataset. Also, there are less columns in the test dataset. Upon inspection, it is found that the test dataset does not have the 'revenue' column which is the target variable that we are trying to predict.
#df_test.columns.to_list()

# %%
# Inspecting proportion of missing values in the transactioRevenue column (This info is useful for the classification model)
print('The proportion of missing values in the transactionRevenue column is:',df_train['transactionRevenue'].isnull().sum()/len(df_train))
# Inspecting the number of non-null values in the transactioRevenue column ( The subset is useful for the regression model)
print('The number of non-null values in the transactionRevenue column is:',df_train['transactionRevenue'].notnull().sum())
# Out:
# The proportion of missing values in the transactionRevenue column is: 0.9872572768529513
# The number of non-null values in the transactionRevenue column is: 11515

# %%
def subset_data(df):
    reg_df=df[df['transactionRevenue'].notnull()]

    return reg_df

# %%
reg_df=subset_data(df_train)

# %%
reg_df.shape
# Out:
# (11515, 55)

# %% [markdown]
# #### Exported the subset of the training dataset that contains the non-null values of the transactionRevenue column to a csv file for use in the regression model

# %%
pwd = os.getcwd()
pwd = os.getcwd()
filename = "reg_df.csv"  # Name of the file
filepath2 = os.path.join(pwd, "Data", filename)

# Save your DataFrame to CSV
reg_df.to_csv(filepath2, index=False)

# %% [markdown]
# ### Basic Data Exploration and Cleaning

# %%
df=pd.read_csv(filepath, parse_dates=['date'])
# Out:
# /Users/yvankammelu/anaconda3/envs/causalml-py38/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (2,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Exploring the dataset; checking the data types of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903653 entries, 0 to 903652
# Data columns (total 55 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   channelGrouping                      903653 non-null  object
#  1   date                                 903653 non-null  datetime64[ns]
#  2   fullVisitorId                        903653 non-null  object
#  3   sessionId                            903653 non-null  object
#  4   socialEngagementType                 903653 non-null  object
#  5   visitId                              903653 non-null  int64
#  6   visitNumber                          903653 non-null  int64
#  7   visitStartTime                       903653 non-null  int64
#  8   continent                            903653 non-null  object
#  9   subContinent                         903653 non-null  object
#  10  country                              903653 non-null  object
#  11  region                               903653 non-null  object
#  12  metro                                903653 non-null  object
#  13  city                                 903653 non-null  object
#  14  cityId                               903653 non-null  object
#  15  networkDomain                        903653 non-null  object
#  16  latitude                             903653 non-null  object
#  17  longitude                            903653 non-null  object
#  18  networkLocation                      903653 non-null  object
#  19  browser                              903653 non-null  object
#  20  browserVersion                       903653 non-null  object
#  21  browserSize                          903653 non-null  object
#  22  operatingSystem                      903653 non-null  object
#  23  operatingSystemVersion               903653 non-null  object
#  24  isMobile                             903653 non-null  bool
#  25  mobileDeviceBranding                 903653 non-null  object
#  26  mobileDeviceModel                    903653 non-null  object
#  27  mobileInputSelector                  903653 non-null  object
#  28  mobileDeviceInfo                     903653 non-null  object
#  29  mobileDeviceMarketingName            903653 non-null  object
#  30  flashVersion                         903653 non-null  object
#  31  language                             903653 non-null  object
#  32  screenColors                         903653 non-null  object
#  33  screenResolution                     903653 non-null  object
#  34  deviceCategory                       903653 non-null  object
#  35  visits                               903653 non-null  int64
#  36  hits                                 903653 non-null  int64
#  37  pageviews                            903553 non-null  float64
#  38  bounces                              450630 non-null  float64
#  39  newVisits                            703060 non-null  float64
#  40  transactionRevenue                   11515 non-null   float64
#  41  campaign                             903653 non-null  object
#  42  source                               903653 non-null  object
#  43  medium                               903653 non-null  object
#  44  keyword                              400724 non-null  object
#  45  adwordsClickInfo.criteriaParameters  903653 non-null  object
#  46  isTrueDirect                         274005 non-null  object
#  47  referralPath                         330941 non-null  object
#  48  adwordsClickInfo.page                21460 non-null   float64
#  49  adwordsClickInfo.slot                21460 non-null   object
#  50  adwordsClickInfo.gclId               21561 non-null   object
#  51  adwordsClickInfo.adNetworkType       21460 non-null   object
#  52  adwordsClickInfo.isVideoAd           21460 non-null   object
#  53  adContent                            10946 non-null   object
#  54  campaignCode                         1 non-null       object
# dtypes: bool(1), datetime64[ns](1), float64(5), int64(5), object(43)
# memory usage: 373.2+ MB

# %%
print('The dimensions of the training dataset are:', df.shape)
# Out:
# The dimensions of the training dataset are: (903653, 55)

# %%
# Checking null values in the dataset
# Note that null values in the transactionRevenue column means that the customer did not make a purchase
df.isnull().sum()
# Out:
# channelGrouping                             0
# date                                        0
# fullVisitorId                               0
# sessionId                                   0
# socialEngagementType                        0
# visitId                                     0
# visitNumber                                 0
# visitStartTime                              0
# continent                                   0
# subContinent                                0
# country                                     0
# region                                      0
# metro                                       0
# city                                        0
# cityId                                      0
# networkDomain                               0
# latitude                                    0
# longitude                                   0
# networkLocation                             0
# browser                                     0
# browserVersion                              0
# browserSize                                 0
# operatingSystem                             0
# operatingSystemVersion                      0
# isMobile                                    0
# mobileDeviceBranding                        0
# mobileDeviceModel                           0
# mobileInputSelector                         0
# mobileDeviceInfo                            0
# mobileDeviceMarketingName                   0
# flashVersion                                0
# language                                    0
# screenColors                                0
# screenResolution                            0
# deviceCategory                              0
# visits                                      0
# hits                                        0
# pageviews                                 100
# bounces                                453023
# newVisits                              200593
# transactionRevenue                     892138
# campaign                                    0
# source                                      0
# medium                                      0
# keyword                                502929
# adwordsClickInfo.criteriaParameters         0
# isTrueDirect                           629648
# referralPath                           572712
# adwordsClickInfo.page                  882193
# adwordsClickInfo.slot                  882193
# adwordsClickInfo.gclId                 882092
# adwordsClickInfo.adNetworkType         882193
# adwordsClickInfo.isVideoAd             882193
# adContent                              892707
# campaignCode                           903652
# dtype: int64

# %%
# Iterate over all column names in the DataFrame
for column in df.columns:
    print(f"Value counts for {column}:")
    print(df[column].value_counts(dropna=False))  # Include NaN counts
    print("\n")  # Adds a newline for better readability between columns
# Out:
# Value counts for channelGrouping:
# Organic Search    381561
# Social            226117
# Direct            143026
# Referral          104838
# Paid Search        25326
# Affiliates         16403
# Display             6262
# (Other)              120
# Name: channelGrouping, dtype: int64
#
#
# Value counts for date:
# 2016-11-28    4807
# 2016-11-15    4685
# 2016-11-14    4466
# 2016-11-30    4435
# 2016-10-26    4375
#               ...
# 2017-05-14    1290
# 2017-05-13    1251
# 2016-12-30    1232
# 2016-12-24    1231
# 2016-12-31    1211
# Name: date, Length: 366, dtype: int64
#
#
# Value counts for fullVisitorId:
# 1957458976293878100    262
# 824839726118485274     245
# 1856749147915772585    188
# 3608475193341679870    186
# 3269834865385146569    152
#                       ...
# 6922417057126708584      1
# 2234301967377757304      1
# 842787683906860984       1
# 7313631604993900517      1
# 5744576632396406899      1
# Name: fullVisitorId, Length: 723803, dtype: int64
#
#
# Value counts for sessionId:
# 14108533830165900_1482391162      2
# 4853581114722495742_1476685840    2
# 0405996727678488611_1500187709    2
# 3253295852378145181_1476341873    2
# 2072942859070557608_1481787032    2
#                                  ..
# 6421306558690440480_1500861832    1
# 7011940795194012046_1500796565    1
# 8294385584898851755_1500829406    1
# 7593097865204451563_1500869899    1
# 0814900163617805053_1483574474    1
# Name: sessionId, Length: 902755, dtype: int64
#
#
# Value counts for socialEngagementType:
# Not Socially Engaged    903653
# Name: socialEngagementType, dtype: int64
#
#
# Value counts for visitId:
# 1493146175    8
# 1478345904    6
# 1481369525    6
# 1484649802    6
# 1500856602    5
#              ..
# 1473787315    1
# 1473834449    1
# 1473757030    1
# 1473777777    1
# 1483574474    1
# Name: visitId, Length: 886303, dtype: int64
#
#
# Value counts for visitNumber:
# 1      703060
# 2       92548
# 3       35843
# 4       19157
# 5       11615
#         ...
# 364         1
# 363         1
# 370         1
# 307         1
# 387         1
# Name: visitNumber, Length: 384, dtype: int64
#
#
# Value counts for visitStartTime:
# 1493146175    8
# 1478345904    6
# 1484649802    6
# 1481369525    6
# 1495031359    5
#              ..
# 1473754883    1
# 1473761223    1
# 1473799196    1
# 1473750777    1
# 1483574474    1
# Name: visitStartTime, Length: 887159, dtype: int64
#
#
# Value counts for continent:
# Americas     450377
# Asia         223698
# Europe       198311
# Oceania       15054
# Africa        14745
# (not set)      1468
# Name: continent, dtype: int64
#
#
# Value counts for subContinent:
# Northern America      390657
# Southeast Asia         77800
# Southern Asia          59321
# Western Europe         59114
# Northern Europe        58168
# Eastern Asia           46919
# Eastern Europe         45249
# South America          41731
# Western Asia           38443
# Southern Europe        35780
# Central America        15583
# Australasia            14893
# Northern Africa         7683
# Western Africa          2573
# Caribbean               2406
# Southern Africa         2169
# Eastern Africa          1927
# (not set)               1468
# Central Asia            1215
# Middle Africa            393
# Melanesia                 81
# Micronesian Region        55
# Polynesia                 25
# Name: subContinent, dtype: int64
#
#
# Value counts for country:
# United States            364744
# India                     51140
# United Kingdom            37393
# Canada                    25869
# Vietnam                   24598
#                           ...
# St. Pierre & Miquelon         1
# Anguilla                      1
# American Samoa                1
# Åland Islands                 1
# St. Barthélemy                1
# Name: country, Length: 222, dtype: int64
#
#
# Value counts for region:
# not available in demo dataset    508229
# California                       107495
# (not set)                         27827
# New York                          26433
# England                           13198
#                                   ...
# Leiria District                       6
# Assam                                 6
# Kumamoto Prefecture                   5
# San Salvador Department               5
# Montana                               3
# Name: region, Length: 376, dtype: int64
#
#
# Value counts for metro:
# not available in demo dataset        508229
# (not set)                            201766
# San Francisco-Oakland-San Jose CA     95913
# New York NY                           26917
# London                                12571
#                                       ...
# Chattanooga TN                            6
# Springfield-Holyoke MA                    6
# Providence-New Bedford,MA                 6
# Boise ID                                  3
# Butte-Bozeman MT                          3
# Name: metro, Length: 94, dtype: int64
#
#
# Value counts for city:
# not available in demo dataset    508229
# Mountain View                     40884
# (not set)                         34262
# New York                          26371
# San Francisco                     20329
#                                   ...
# Douglasville                          5
# San Salvador                          5
# Daly City                             4
# Boise                                 3
# Bozeman                               3
# Name: city, Length: 649, dtype: int64
#
#
# Value counts for cityId:
# not available in demo dataset    903653
# Name: cityId, dtype: int64
#
#
# Value counts for networkDomain:
# (not set)            244881
# unknown.unknown      146034
# comcast.net           28743
# rr.com                14827
# verizon.net           13637
#                       ...
# panasonic.jp              1
# flair.cz                  1
# kwanglimyhi.co.id         1
# nursat.kz                 1
# xpressgt.co.za            1
# Name: networkDomain, Length: 28064, dtype: int64
#
#
# Value counts for latitude:
# not available in demo dataset    903653
# Name: latitude, dtype: int64
#
#
# Value counts for longitude:
# not available in demo dataset    903653
# Name: longitude, dtype: int64
#
#
# Value counts for networkLocation:
# not available in demo dataset    903653
# Name: networkLocation, dtype: int64
#
#
# Value counts for browser:
# Chrome                                         620364
# Safari                                         182245
# Firefox                                         37069
# Internet Explorer                               19375
# Edge                                            10205
# Android Webview                                  7865
# Safari (in-app)                                  6850
# Opera Mini                                       6139
# Opera                                            5643
# UC Browser                                       2427
# YaBrowser                                        2096
# Coc Coc                                           727
# Amazon Silk                                       561
# Android Browser                                   553
# Mozilla Compatible Agent                          374
# MRCHROME                                          263
# Maxthon                                           246
# BlackBerry                                        184
# Nintendo Browser                                  140
# Puffin                                             93
# Nokia Browser                                      67
# Iron                                               33
# LYF_LS_4002_12                                     21
# SeaMonkey                                          15
# Seznam                                             11
# Mozilla                                            11
# Apple-iPhone7C2                                     9
# (not set)                                           8
# 0                                                   7
# Nichrome                                            7
# osee2unifiedRelease                                 5
# Lunascape                                           5
# DASH_JR_3G                                          4
# ThumbSniper                                         3
# no-ua                                               3
# LYF_LS_4002_11                                      3
# Android Runtime                                     2
# NokiaE52-1                                          2
# MQQBrowser                                          2
# YE                                                  2
# subjectAgent: NoticiasBoom                          1
# TCL P500M                                           1
# Reddit                                              1
# Hisense M20-M_LTE                                   1
# ADM                                                 1
# User Agent                                          1
# [Use default User-agent string] LIVRENPOCHE         1
# DoCoMo                                              1
# HTC802t_TD                                          1
# Changa 99695759                                     1
# IE with Chrome Frame                                1
# Konqueror                                           1
# M5                                                  1
# CSM Click                                           1
# Name: browser, dtype: int64
#
#
# Value counts for browserVersion:
# not available in demo dataset    903653
# Name: browserVersion, dtype: int64
#
#
# Value counts for browserSize:
# not available in demo dataset    903653
# Name: browserSize, dtype: int64
#
#
# Value counts for operatingSystem:
# Windows          350072
# Macintosh        253938
# Android          123892
# iOS              107665
# Linux             35034
# Chrome OS         26337
# (not set)          4695
# Windows Phone      1216
# Samsung             280
# BlackBerry          218
# Nintendo Wii        100
# Firefox OS           89
# Xbox                 66
# Nintendo WiiU        35
# FreeBSD               9
# Nokia                 2
# OpenBSD               2
# NTT DoCoMo            1
# Nintendo 3DS          1
# SunOS                 1
# Name: operatingSystem, dtype: int64
#
#
# Value counts for operatingSystemVersion:
# not available in demo dataset    903653
# Name: operatingSystemVersion, dtype: int64
#
#
# Value counts for isMobile:
# False    664530
# True     239123
# Name: isMobile, dtype: int64
#
#
# Value counts for mobileDeviceBranding:
# not available in demo dataset    903653
# Name: mobileDeviceBranding, dtype: int64
#
#
# Value counts for mobileDeviceModel:
# not available in demo dataset    903653
# Name: mobileDeviceModel, dtype: int64
#
#
# Value counts for mobileInputSelector:
# not available in demo dataset    903653
# Name: mobileInputSelector, dtype: int64
#
#
# Value counts for mobileDeviceInfo:
# not available in demo dataset    903653
# Name: mobileDeviceInfo, dtype: int64
#
#
# Value counts for mobileDeviceMarketingName:
# not available in demo dataset    903653
# Name: mobileDeviceMarketingName, dtype: int64
#
#
# Value counts for flashVersion:
# not available in demo dataset    903653
# Name: flashVersion, dtype: int64
#
#
# Value counts for language:
# not available in demo dataset    903653
# Name: language, dtype: int64
#
#
# Value counts for screenColors:
# not available in demo dataset    903653
# Name: screenColors, dtype: int64
#
#
# Value counts for screenResolution:
# not available in demo dataset    903653
# Name: screenResolution, dtype: int64
#
#
# Value counts for deviceCategory:
# desktop    664479
# mobile     208725
# tablet      30449
# Name: deviceCategory, dtype: int64
#
#
# Value counts for visits:
# 1    903653
# Name: visits, dtype: int64
#
#
# Value counts for hits:
# 1      446754
# 2      137952
# 3       70402
# 4       42444
# 5       30939
#         ...
# 249         1
# 406         1
# 217         1
# 240         1
# 237         1
# Name: hits, Length: 274, dtype: int64
#
#
# Value counts for pageviews:
# 1.0      452522
# 2.0      143770
# 3.0       73835
# 4.0       45192
# 5.0       33411
#           ...
# 141.0         1
# 351.0         1
# 197.0         1
# 305.0         1
# 186.0         1
# Name: pageviews, Length: 214, dtype: int64
#
#
# Value counts for bounces:
# NaN    453023
# 1.0    450630
# Name: bounces, dtype: int64
#
#
# Value counts for newVisits:
# 1.0    703060
# NaN    200593
# Name: newVisits, dtype: int64
#
#
# Value counts for transactionRevenue:
# NaN            892138
# 16990000.0        256
# 18990000.0        189
# 33590000.0        187
# 44790000.0        170
#                 ...
# 88660000.0          1
# 135800000.0         1
# 34150000.0          1
# 175410000.0         1
# 69390000.0          1
# Name: transactionRevenue, Length: 5333, dtype: int64
#
#
# Value counts for campaign:
# (not set)                                          865347
# Data Share Promo                                    16403
# AW - Dynamic Search Ads Whole Site                  14244
# AW - Accessories                                     7070
# test-liyuhz                                           392
# AW - Electronics                                       96
# Retail (DO NOT EDIT owners nophakun and tianyu)        50
# AW - Apparel                                           46
# All Products                                            4
# Data Share                                              1
# Name: campaign, dtype: int64
#
#
# Value counts for source:
# google                                               400788
# youtube.com                                          212602
# (direct)                                             143028
# mall.googleplex.com                                   66416
# Partners                                              16411
#                                                       ...
# google.se                                                 1
# 0.shared.bow.cat2.ads-bow.vu.borg.google.com:9883         1
# myaccount.google.com                                      1
# 0.shared.bow.cat2.ads-bow.tg.borg.google.com:9864         1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898         1
# Name: source, Length: 380, dtype: int64
#
#
# Value counts for medium:
# organic      381561
# referral     330955
# (none)       143026
# cpc           25326
# affiliate     16403
# cpm            6262
# (not set)       120
# Name: medium, dtype: int64
#
#
# Value counts for keyword:
# NaN                                502929
# (not provided)                     366363
# 6qEhsCssdK0z36ri                    11503
# (Remarketing/Content targeting)      2298
# 1hZbAqLCbjwfgOH7                     2264
#                                     ...
# google store t-sthrts                   1
# google clotging store                   1
# accessories                             1
# google ti shirt                         1
# google shirt buy online                 1
# Name: keyword, Length: 3660, dtype: int64
#
#
# Value counts for adwordsClickInfo.criteriaParameters:
# not available in demo dataset    903653
# Name: adwordsClickInfo.criteriaParameters, dtype: int64
#
#
# Value counts for isTrueDirect:
# NaN     629648
# True    274005
# Name: isTrueDirect, dtype: int64
#
#
# Value counts for referralPath:
# NaN                                                                                                                                                                              572712
# /                                                                                                                                                                                 75523
# /yt/about/                                                                                                                                                                        71036
# /analytics/web/                                                                                                                                                                   14620
# /yt/about/tr/                                                                                                                                                                     14599
#                                                                                                                                                                                   ...
# /from=0/bd_page_type=1/ssid=0/uid=0/pu=usm%402%2Csz%40320_1001%2Cta%40iphone_2_6.0_3_537/baiduid=188B613C9AE2B02E2FCA141428006590/w=0_10_/t=iphone/l=3/tc                             1
# /from=1000541v/bd_page_type=1/ssid=0/uid=0/pu=usm%401%2Csz%40320_1001%2Cta%40iphone_2_5.1_3_/baiduid=BD78D77BD1399A554CA37FEDA641D72B/w=0_10_/t=iphone/l=3/tc                         1
# /request                                                                                                                                                                              1
# /from=1015785e/bd_page_type=1/ssid=0/uid=0/pu=usm%402%2Csz%401320_2001%2Cta%40iphone_1_9.3_3_601/baiduid=39801B0966F60CD0C5500E77C58B1AE1/w=0_10_google+store/t=iphone/l=3/tc         1
# /mail/mu/mp/509/                                                                                                                                                                      1
# Name: referralPath, Length: 1476, dtype: int64
#
#
# Value counts for adwordsClickInfo.page:
# NaN     882193
# 1.0      21362
# 2.0         73
# 3.0         10
# 5.0          7
# 7.0          3
# 9.0          2
# 4.0          2
# 14.0         1
# Name: adwordsClickInfo.page, dtype: int64
#
#
# Value counts for adwordsClickInfo.slot:
# NaN    882193
# Top     20956
# RHS       504
# Name: adwordsClickInfo.slot, dtype: int64
#
#
# Value counts for adwordsClickInfo.gclId:
# NaN                                                                                           882092
# Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3ZdwYO8GTsjiBFd5MPHStZa9y_9NCrI8X97oaAglc8P8HAQ        70
# Cj0KEQjw1ee_BRD3hK6x993YzeoBEiQA5RH_BEA562M9tvl_mtnAFvtDnDqOQRp1RvxMMgwjcX1LAfwaAj4o8P8HAQ        41
# CJH1vbf94M8CFUElgQodyakHgQ                                                                        29
# Cj0KEQiAw_DEBRChnYiQ_562gsEBEiQA4LcssmB_RWgvpPnltzlzj5rGwqx5lk87wC5CjfcqzneNZewaAiAp8P8HAQ        27
#                                                                                                ...
# CNfOlNvk4s0CFQkyaQodN5gIIA                                                                         1
# CI-C8uGf384CFYpbhgodxCIDqg                                                                         1
# Cj0KEQjw0f-9BRCF9-D60_n4rKcBEiQAnXW4-1fuNQ3PSaw-8IpyhC3voXU2MSZojUnnIpkHW6csjLwaArcp8P8HAQ         1
# Cj0KEQjw0f-9BRCF9-D60_n4rKcBEiQAnXW4-yZ0QKHMEn_RGRULJjMWfeRTd3Qi7Vk6Q0cX-uYNjbkaAvjc8P8HAQ         1
# CjwKEAiA17LDBRDElqOGq8vR7m8SJAA1AC0_0wzbDX0fd-gzNVm4iuZRBFQ6id5RBK7XQZGOS1kIHRoCXJPw_wcB           1
# Name: adwordsClickInfo.gclId, Length: 17775, dtype: int64
#
#
# Value counts for adwordsClickInfo.adNetworkType:
# NaN                882193
# Google Search       21453
# Search partners         7
# Name: adwordsClickInfo.adNetworkType, dtype: int64
#
#
# Value counts for adwordsClickInfo.isVideoAd:
# NaN      882193
# False     21460
# Name: adwordsClickInfo.isVideoAd, dtype: int64
#
#
# Value counts for adContent:
# NaN                                            892707
# Google Merchandise Collection                    5122
# Google Online Store                              1245
# Display Ad created 3/11/14                        967
# Full auto ad IMAGE ONLY                           822
# Ad from 12/13/16                                  610
# Ad from 11/3/16                                   489
# Display Ad created 3/11/15                        392
# {KeyWord:Google Brand Items}                      251
# {KeyWord:Google Merchandise}                      155
# Ad from 11/7/16                                   123
# First Full Auto Template Test Ad                   87
# Google Merchandise                                 87
# 20% discount                                       75
# {KeyWord:Google Branded Gear}                      67
# {KeyWord:Looking for Google Bags?}                 65
# Swag with Google Logos                             64
# Display Ad created 11/17/14                        50
# {KeyWord:Want Google Stickers?}                    42
# JD_5a_v1                                           41
# {KeyWord:Google Drinkware}                         32
# {KeyWord:Google Men's T-Shirts}                    30
# LeEco_1a                                           25
# {KeyWord:Google Branded Kit}                       16
# Full auto ad TEXT ONLY                             16
# {KeyWord:Google Branded Apparel}                   10
# Want Google Sunglasses                              8
# Google Paraphernalia                                7
# Full auto ad TEXT/NATIVE                            7
# {KeyWord:Google Branded Outerwear}                  5
# Google Store                                        4
# {KeyWord:Want Google Pet Toys?}                     4
# Official Google Merchandise - Fast Shipping         4
# free shipping                                       3
# url_builder                                         3
# Ad from 2/17/17                                     3
# Full auto ad NATIVE ONLY                            3
# Full auto ad with Primary Color                     3
# Google store                                        2
# Free Shipping!                                      2
# google store                                        1
# GA Help Center                                      1
# Swag w/ Google Logos                                1
# visit us again                                      1
# Men's-Outerwear Google Apparel                      1
# Name: adContent, dtype: int64
#
#
# Value counts for campaignCode:
# NaN              903652
# 11251kjhkvahf         1
# Name: campaignCode, dtype: int64

# %% [markdown]
# channelgrouping: other?
# socialEngagementType: Drop becasue all values are unique
# continent and subcontinent: (not set): DROP

# %% [markdown]
# ### Continent

# %%
rows_to_drop = df[(df['continent'] == "(not set)") & (df['subContinent'] == "(not set)")].index
df.drop(rows_to_drop, inplace=True)

for column in df.columns:
    print(f"Value counts for {column}:")
    print(df[column].value_counts(dropna=False))  # Include NaN counts
    print("\n")  # Adds a newline for better readability between columns
# Out:
# Value counts for channelGrouping:
# Organic Search    380961
# Social            225664
# Direct            142709
# Referral          104790
# Paid Search        25307
# Affiliates         16372
# Display             6262
# (Other)              120
# Name: channelGrouping, dtype: int64
#
#
# Value counts for date:
# 2016-11-28    4799
# 2016-11-15    4679
# 2016-11-14    4460
# 2016-11-30    4432
# 2016-10-26    4372
#               ...
# 2017-05-14    1290
# 2017-05-13    1250
# 2016-12-30    1230
# 2016-12-24    1227
# 2016-12-31    1210
# Name: date, Length: 366, dtype: int64
#
#
# Value counts for fullVisitorId:
# 1957458976293878100    262
# 824839726118485274     245
# 1856749147915772585    188
# 3608475193341679870    186
# 3269834865385146569    152
#                       ...
# 7408034330202575393      1
# 7969358389793770411      1
# 4908708365405540995      1
# 7581654999621349504      1
# 5744576632396406899      1
# Name: fullVisitorId, Length: 722497, dtype: int64
#
#
# Value counts for sessionId:
# 8217470092518351317_1498632649    2
# 8570311568237919916_1480406145    2
# 2060893843108083179_1470206549    2
# 6131452703406026002_1470639428    2
# 5392466244267026621_1499583386    2
#                                  ..
# 8309168698447235258_1482190379    1
# 9469198503600982492_1482156323    1
# 7807865769648454429_1482163747    1
# 8549170173974341161_1482158068    1
# 0814900163617805053_1483574474    1
# Name: sessionId, Length: 901288, dtype: int64
#
#
# Value counts for socialEngagementType:
# Not Socially Engaged    902185
# Name: socialEngagementType, dtype: int64
#
#
# Value counts for visitId:
# 1493146175    8
# 1478345904    6
# 1484649802    6
# 1481369525    6
# 1494374199    5
#              ..
# 1473798393    1
# 1473761246    1
# 1473786618    1
# 1473805709    1
# 1483574474    1
# Name: visitId, Length: 884878, dtype: int64
#
#
# Value counts for visitNumber:
# 1      701732
# 2       92469
# 3       35816
# 4       19147
# 5       11611
#         ...
# 364         1
# 363         1
# 370         1
# 307         1
# 387         1
# Name: visitNumber, Length: 384, dtype: int64
#
#
# Value counts for visitStartTime:
# 1493146175    8
# 1484649802    6
# 1478345904    6
# 1481369525    6
# 1495031359    5
#              ..
# 1473803373    1
# 1473783428    1
# 1473823265    1
# 1473782006    1
# 1483574474    1
# Name: visitStartTime, Length: 885733, dtype: int64
#
#
# Value counts for continent:
# Americas    450377
# Asia        223698
# Europe      198311
# Oceania      15054
# Africa       14745
# Name: continent, dtype: int64
#
#
# Value counts for subContinent:
# Northern America      390657
# Southeast Asia         77800
# Southern Asia          59321
# Western Europe         59114
# Northern Europe        58168
# Eastern Asia           46919
# Eastern Europe         45249
# South America          41731
# Western Asia           38443
# Southern Europe        35780
# Central America        15583
# Australasia            14893
# Northern Africa         7683
# Western Africa          2573
# Caribbean               2406
# Southern Africa         2169
# Eastern Africa          1927
# Central Asia            1215
# Middle Africa            393
# Melanesia                 81
# Micronesian Region        55
# Polynesia                 25
# Name: subContinent, dtype: int64
#
#
# Value counts for country:
# United States            364744
# India                     51140
# United Kingdom            37393
# Canada                    25869
# Vietnam                   24598
#                           ...
# St. Pierre & Miquelon         1
# Anguilla                      1
# American Samoa                1
# Åland Islands                 1
# St. Barthélemy                1
# Name: country, Length: 221, dtype: int64
#
#
# Value counts for region:
# not available in demo dataset    508211
# California                       107494
# New York                          26431
# (not set)                         26384
# England                           13198
#                                   ...
# Leiria District                       6
# Assam                                 6
# Kumamoto Prefecture                   5
# San Salvador Department               5
# Montana                               3
# Name: region, Length: 376, dtype: int64
#
#
# Value counts for metro:
# not available in demo dataset        508211
# (not set)                            200319
# San Francisco-Oakland-San Jose CA     95912
# New York NY                           26915
# London                                12571
#                                       ...
# Chattanooga TN                            6
# Springfield-Holyoke MA                    6
# Providence-New Bedford,MA                 6
# Boise ID                                  3
# Butte-Bozeman MT                          3
# Name: metro, Length: 94, dtype: int64
#
#
# Value counts for city:
# not available in demo dataset    508211
# Mountain View                     40884
# (not set)                         32820
# New York                          26369
# San Francisco                     20328
#                                   ...
# Douglasville                          5
# San Salvador                          5
# Daly City                             4
# Boise                                 3
# Bozeman                               3
# Name: city, Length: 649, dtype: int64
#
#
# Value counts for cityId:
# not available in demo dataset    902185
# Name: cityId, dtype: int64
#
#
# Value counts for networkDomain:
# (not set)          244549
# unknown.unknown    145660
# comcast.net         28743
# rr.com              14827
# verizon.net         13637
#                     ...
# fct.pt                  1
# sok.fi                  1
# watertownps.org         1
# netwave.com             1
# xpressgt.co.za          1
# Name: networkDomain, Length: 28023, dtype: int64
#
#
# Value counts for latitude:
# not available in demo dataset    902185
# Name: latitude, dtype: int64
#
#
# Value counts for longitude:
# not available in demo dataset    902185
# Name: longitude, dtype: int64
#
#
# Value counts for networkLocation:
# not available in demo dataset    902185
# Name: networkLocation, dtype: int64
#
#
# Value counts for browser:
# Chrome                                         619501
# Safari                                         182145
# Firefox                                         36997
# Internet Explorer                               19192
# Edge                                            10199
# Android Webview                                  7855
# Safari (in-app)                                  6837
# Opera Mini                                       5985
# Opera                                            5605
# UC Browser                                       2413
# YaBrowser                                        2093
# Coc Coc                                           726
# Amazon Silk                                       561
# Android Browser                                   548
# Mozilla Compatible Agent                          370
# MRCHROME                                          263
# Maxthon                                           245
# BlackBerry                                        183
# Nintendo Browser                                  140
# Puffin                                             93
# Nokia Browser                                      67
# Iron                                               33
# LYF_LS_4002_12                                     21
# SeaMonkey                                          15
# Seznam                                             11
# Mozilla                                            11
# Apple-iPhone7C2                                     9
# (not set)                                           8
# 0                                                   7
# Nichrome                                            7
# osee2unifiedRelease                                 5
# Lunascape                                           5
# DASH_JR_3G                                          4
# ThumbSniper                                         3
# no-ua                                               3
# LYF_LS_4002_11                                      3
# Android Runtime                                     2
# NokiaE52-1                                          2
# MQQBrowser                                          2
# YE                                                  2
# subjectAgent: NoticiasBoom                          1
# TCL P500M                                           1
# Reddit                                              1
# Hisense M20-M_LTE                                   1
# ADM                                                 1
# User Agent                                          1
# [Use default User-agent string] LIVRENPOCHE         1
# DoCoMo                                              1
# HTC802t_TD                                          1
# Changa 99695759                                     1
# IE with Chrome Frame                                1
# Konqueror                                           1
# M5                                                  1
# CSM Click                                           1
# Name: browser, dtype: int64
#
#
# Value counts for browserVersion:
# not available in demo dataset    902185
# Name: browserVersion, dtype: int64
#
#
# Value counts for browserSize:
# not available in demo dataset    902185
# Name: browserSize, dtype: int64
#
#
# Value counts for operatingSystem:
# Windows          349254
# Macintosh        253824
# Android          123687
# iOS              107587
# Linux             34982
# Chrome OS         26325
# (not set)          4517
# Windows Phone      1210
# Samsung             278
# BlackBerry          217
# Nintendo Wii        100
# Firefox OS           87
# Xbox                 66
# Nintendo WiiU        35
# FreeBSD               9
# Nokia                 2
# OpenBSD               2
# NTT DoCoMo            1
# Nintendo 3DS          1
# SunOS                 1
# Name: operatingSystem, dtype: int64
#
#
# Value counts for operatingSystemVersion:
# not available in demo dataset    902185
# Name: operatingSystemVersion, dtype: int64
#
#
# Value counts for isMobile:
# False    663474
# True     238711
# Name: isMobile, dtype: int64
#
#
# Value counts for mobileDeviceBranding:
# not available in demo dataset    902185
# Name: mobileDeviceBranding, dtype: int64
#
#
# Value counts for mobileDeviceModel:
# not available in demo dataset    902185
# Name: mobileDeviceModel, dtype: int64
#
#
# Value counts for mobileInputSelector:
# not available in demo dataset    902185
# Name: mobileInputSelector, dtype: int64
#
#
# Value counts for mobileDeviceInfo:
# not available in demo dataset    902185
# Name: mobileDeviceInfo, dtype: int64
#
#
# Value counts for mobileDeviceMarketingName:
# not available in demo dataset    902185
# Name: mobileDeviceMarketingName, dtype: int64
#
#
# Value counts for flashVersion:
# not available in demo dataset    902185
# Name: flashVersion, dtype: int64
#
#
# Value counts for language:
# not available in demo dataset    902185
# Name: language, dtype: int64
#
#
# Value counts for screenColors:
# not available in demo dataset    902185
# Name: screenColors, dtype: int64
#
#
# Value counts for screenResolution:
# not available in demo dataset    902185
# Name: screenResolution, dtype: int64
#
#
# Value counts for deviceCategory:
# desktop    663423
# mobile     208348
# tablet      30414
# Name: deviceCategory, dtype: int64
#
#
# Value counts for visits:
# 1    902185
# Name: visits, dtype: int64
#
#
# Value counts for hits:
# 1      445873
# 2      137734
# 3       70292
# 4       42396
# 5       30893
#         ...
# 249         1
# 406         1
# 217         1
# 240         1
# 237         1
# Name: hits, Length: 274, dtype: int64
#
#
# Value counts for pageviews:
# 1.0      451630
# 2.0      143527
# 3.0       73735
# 4.0       45147
# 5.0       33368
#           ...
# 141.0         1
# 351.0         1
# 197.0         1
# 305.0         1
# 186.0         1
# Name: pageviews, Length: 214, dtype: int64
#
#
# Value counts for bounces:
# NaN    452441
# 1.0    449744
# Name: bounces, dtype: int64
#
#
# Value counts for newVisits:
# 1.0    701732
# NaN    200453
# Name: newVisits, dtype: int64
#
#
# Value counts for transactionRevenue:
# NaN            890676
# 16990000.0        256
# 18990000.0        189
# 33590000.0        187
# 44790000.0        170
#                 ...
# 35320000.0          1
# 198580000.0         1
# 804820000.0         1
# 54610000.0          1
# 69390000.0          1
# Name: transactionRevenue, Length: 5330, dtype: int64
#
#
# Value counts for campaign:
# (not set)                                          863923
# Data Share Promo                                    16372
# AW - Dynamic Search Ads Whole Site                  14235
# AW - Accessories                                     7066
# test-liyuhz                                           392
# AW - Electronics                                       96
# Retail (DO NOT EDIT owners nophakun and tianyu)        50
# AW - Apparel                                           46
# All Products                                            4
# Data Share                                              1
# Name: campaign, dtype: int64
#
#
# Value counts for source:
# google                                               400251
# youtube.com                                          212166
# (direct)                                             142711
# mall.googleplex.com                                   66412
# Partners                                              16380
#                                                       ...
# google.se                                                 1
# 0.shared.bow.cat2.ads-bow.vu.borg.google.com:9883         1
# myaccount.google.com                                      1
# 0.shared.bow.cat2.ads-bow.tg.borg.google.com:9864         1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898         1
# Name: source, Length: 380, dtype: int64
#
#
# Value counts for medium:
# organic      380961
# referral     330454
# (none)       142709
# cpc           25307
# affiliate     16372
# cpm            6262
# (not set)       120
# Name: medium, dtype: int64
#
#
# Value counts for keyword:
# NaN                                502008
# (not provided)                     365873
# 6qEhsCssdK0z36ri                    11495
# (Remarketing/Content targeting)      2294
# 1hZbAqLCbjwfgOH7                     2263
#                                     ...
# android water bottle                    1
# google store t-sthrts                   1
# google clotging store                   1
# accessories                             1
# google shirt buy online                 1
# Name: keyword, Length: 3651, dtype: int64
#
#
# Value counts for adwordsClickInfo.criteriaParameters:
# not available in demo dataset    902185
# Name: adwordsClickInfo.criteriaParameters, dtype: int64
#
#
# Value counts for isTrueDirect:
# NaN     628594
# True    273591
# Name: isTrueDirect, dtype: int64
#
#
# Value counts for referralPath:
# NaN                                                    571745
# /                                                       75511
# /yt/about/                                              70797
# /analytics/web/                                         14605
# /yt/about/tr/                                           14588
#                                                         ...
# /ads/richmedia/studio/pv2/45678668/dirty/index.html         1
# /ads/richmedia/studio/pv2/45678672/dirty/index.html         1
# /class_sections/14064/modules/9450/activities/99087         1
# /~kristiyan/2082_pure_mix/index.html                        1
# /mail/mu/mp/509/                                            1
# Name: referralPath, Length: 1470, dtype: int64
#
#
# Value counts for adwordsClickInfo.page:
# NaN     880738
# 1.0      21349
# 2.0         73
# 3.0         10
# 5.0          7
# 7.0          3
# 9.0          2
# 4.0          2
# 14.0         1
# Name: adwordsClickInfo.page, dtype: int64
#
#
# Value counts for adwordsClickInfo.slot:
# NaN    880738
# Top     20943
# RHS       504
# Name: adwordsClickInfo.slot, dtype: int64
#
#
# Value counts for adwordsClickInfo.gclId:
# NaN                                                                                           880637
# Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3ZdwYO8GTsjiBFd5MPHStZa9y_9NCrI8X97oaAglc8P8HAQ        70
# Cj0KEQjw1ee_BRD3hK6x993YzeoBEiQA5RH_BEA562M9tvl_mtnAFvtDnDqOQRp1RvxMMgwjcX1LAfwaAj4o8P8HAQ        41
# CJH1vbf94M8CFUElgQodyakHgQ                                                                        29
# Cj0KEQiAw_DEBRChnYiQ_562gsEBEiQA4LcssmB_RWgvpPnltzlzj5rGwqx5lk87wC5CjfcqzneNZewaAiAp8P8HAQ        27
#                                                                                                ...
# CNfOlNvk4s0CFQkyaQodN5gIIA                                                                         1
# CI-C8uGf384CFYpbhgodxCIDqg                                                                         1
# Cj0KEQjw0f-9BRCF9-D60_n4rKcBEiQAnXW4-1fuNQ3PSaw-8IpyhC3voXU2MSZojUnnIpkHW6csjLwaArcp8P8HAQ         1
# Cj0KEQjw0f-9BRCF9-D60_n4rKcBEiQAnXW4-yZ0QKHMEn_RGRULJjMWfeRTd3Qi7Vk6Q0cX-uYNjbkaAvjc8P8HAQ         1
# CjwKEAiA17LDBRDElqOGq8vR7m8SJAA1AC0_0wzbDX0fd-gzNVm4iuZRBFQ6id5RBK7XQZGOS1kIHRoCXJPw_wcB           1
# Name: adwordsClickInfo.gclId, Length: 17762, dtype: int64
#
#
# Value counts for adwordsClickInfo.adNetworkType:
# NaN                880738
# Google Search       21440
# Search partners         7
# Name: adwordsClickInfo.adNetworkType, dtype: int64
#
#
# Value counts for adwordsClickInfo.isVideoAd:
# NaN      880738
# False     21447
# Name: adwordsClickInfo.isVideoAd, dtype: int64
#
#
# Value counts for adContent:
# NaN                                            891249
# Google Merchandise Collection                    5118
# Google Online Store                              1245
# Display Ad created 3/11/14                        963
# Full auto ad IMAGE ONLY                           822
# Ad from 12/13/16                                  609
# Ad from 11/3/16                                   488
# Display Ad created 3/11/15                        392
# {KeyWord:Google Brand Items}                      251
# {KeyWord:Google Merchandise}                      155
# Ad from 11/7/16                                   123
# First Full Auto Template Test Ad                   87
# Google Merchandise                                 87
# 20% discount                                       75
# {KeyWord:Google Branded Gear}                      67
# {KeyWord:Looking for Google Bags?}                 65
# Swag with Google Logos                             64
# Display Ad created 11/17/14                        50
# {KeyWord:Want Google Stickers?}                    42
# JD_5a_v1                                           41
# {KeyWord:Google Drinkware}                         32
# {KeyWord:Google Men's T-Shirts}                    30
# LeEco_1a                                           25
# {KeyWord:Google Branded Kit}                       16
# Full auto ad TEXT ONLY                             16
# {KeyWord:Google Branded Apparel}                   10
# Want Google Sunglasses                              8
# Google Paraphernalia                                7
# Full auto ad TEXT/NATIVE                            7
# {KeyWord:Google Branded Outerwear}                  5
# Google Store                                        4
# {KeyWord:Want Google Pet Toys?}                     4
# Official Google Merchandise - Fast Shipping         4
# free shipping                                       3
# url_builder                                         3
# Ad from 2/17/17                                     3
# Full auto ad NATIVE ONLY                            3
# Full auto ad with Primary Color                     3
# Google store                                        2
# Free Shipping!                                      2
# google store                                        1
# GA Help Center                                      1
# Swag w/ Google Logos                                1
# visit us again                                      1
# Men's-Outerwear Google Apparel                      1
# Name: adContent, dtype: int64
#
#
# Value counts for campaignCode:
# NaN              902184
# 11251kjhkvahf         1
# Name: campaignCode, dtype: int64

# %% [markdown]
# ### Country

# %%
# Get the value counts for the 'country' column
country_counts = df['country'].value_counts()

# Iterate through the Series and print each country with its count
for country, count in country_counts.items():
    print(f"{country}: {count}")
# Out:
# United States: 364744
# India: 51140
# United Kingdom: 37393
# Canada: 25869
# Vietnam: 24598
# Turkey: 20522
# Thailand: 20123
# Germany: 19980
# Brazil: 19783
# Japan: 19731
# France: 15832
# Mexico: 13225
# Taiwan: 12996
# Australia: 12698
# Russia: 11662
# Spain: 11658
# Netherlands: 11453
# Italy: 11332
# Poland: 9693
# Indonesia: 9273
# Philippines: 9244
# Singapore: 7172
# Ireland: 6493
# Malaysia: 6439
# Romania: 6428
# Ukraine: 5577
# Israel: 5563
# Peru: 5546
# Sweden: 5315
# South Korea: 5237
# Argentina: 5037
# Colombia: 4880
# Hong Kong: 4718
# Belgium: 4442
# Switzerland: 4427
# Czechia: 4247
# Pakistan: 4010
# China: 3881
# Greece: 3370
# Denmark: 3319
# United Arab Emirates: 3144
# Saudi Arabia: 3132
# Austria: 2796
# Hungary: 2513
# Portugal: 2376
# Egypt: 2343
# Bangladesh: 2297
# Norway: 2250
# New Zealand: 2194
# Venezuela: 2132
# South Africa: 2099
# Algeria: 2055
# Bulgaria: 2046
# Chile: 1950
# Morocco: 1907
# Serbia: 1872
# Slovakia: 1788
# Sri Lanka: 1468
# Nigeria: 1446
# Croatia: 1396
# Ecuador: 1251
# Tunisia: 1194
# Belarus: 976
# Kazakhstan: 968
# Finland: 959
# Dominican Republic: 934
# Bosnia & Herzegovina: 903
# Georgia: 888
# Jordan: 859
# Lithuania: 848
# Macedonia (FYROM): 846
# Kenya: 771
# Puerto Rico: 732
# Slovenia: 729
# Iraq: 711
# Latvia: 705
# Estonia: 656
# Uruguay: 627
# Guatemala: 581
# Azerbaijan: 569
# Costa Rica: 554
# Albania: 547
# Qatar: 535
# Cambodia: 522
# Kuwait: 521
# Panama: 476
# Cyprus: 463
# Kosovo: 435
# Lebanon: 398
# El Salvador: 393
# Ghana: 381
# Côte d’Ivoire: 320
# Moldova: 319
# Bolivia: 318
# Oman: 305
# Armenia: 280
# Tanzania: 260
# Bahrain: 256
# Mongolia: 241
# Nepal: 211
# Myanmar (Burma): 196
# Palestine: 191
# Honduras: 188
# Cameroon: 175
# Malta: 175
# Uganda: 166
# Trinidad & Tobago: 164
# Laos: 161
# Luxembourg: 156
# Jamaica: 153
# Senegal: 151
# Réunion: 145
# Iceland: 142
# Ethiopia: 139
# Nicaragua: 139
# Kyrgyzstan: 134
# Paraguay: 132
# Macau: 115
# Montenegro: 110
# Congo - Kinshasa: 103
# Yemen: 96
# Uzbekistan: 96
# Libya: 92
# Sudan: 92
# Maldives: 89
# Mauritius: 87
# Mozambique: 74
# Brunei: 65
# Martinique: 61
# Zimbabwe: 59
# Angola: 58
# Afghanistan: 57
# Barbados: 55
# Madagascar: 47
# Rwanda: 46
# Fiji: 44
# Benin: 42
# Iran: 41
# Guam: 41
# Jersey: 41
# Bahamas: 40
# Mauritania: 40
# Zambia: 40
# Somalia: 39
# Bermuda: 38
# Haiti: 37
# Burkina Faso: 37
# Namibia: 36
# Mali: 35
# Togo: 32
# Guinea: 31
# Suriname: 30
# Curaçao: 30
# Guadeloupe: 29
# Aruba: 29
# Guyana: 27
# Belize: 27
# Gabon: 25
# Guernsey: 25
# St. Lucia: 24
# New Caledonia: 23
# U.S. Virgin Islands: 22
# Grenada: 22
# Monaco: 21
# Chad: 20
# French Polynesia: 20
# Cape Verde: 18
# Faroe Islands: 18
# French Guiana: 18
# Andorra: 17
# Mayotte: 14
# Swaziland: 14
# Botswana: 14
# Cayman Islands: 14
# Turks & Caicos Islands: 14
# Malawi: 12
# Burundi: 12
# Tajikistan: 12
# Northern Mariana Islands: 12
# Papua New Guinea: 11
# Niger: 10
# Djibouti: 10
# St. Vincent & Grenadines: 10
# Gibraltar: 10
# Syria: 10
# Gambia: 10
# Bhutan: 8
# Sint Maarten: 8
# Liberia: 8
# St. Kitts & Nevis: 8
# Sierra Leone: 8
# Timor-Leste: 7
# Liechtenstein: 7
# Lesotho: 6
# Greenland: 5
# Antigua & Barbuda: 5
# British Virgin Islands: 5
# Turkmenistan: 5
# San Marino: 4
# Central African Republic: 4
# Caribbean Netherlands: 4
# Equatorial Guinea: 4
# Guinea-Bissau: 4
# Isle of Man: 3
# Vanuatu: 3
# Cook Islands: 3
# Dominica: 3
# Congo - Brazzaville: 3
# Seychelles: 3
# Comoros: 2
# Marshall Islands: 2
# Norfolk Island: 1
# Eritrea: 1
# São Tomé & Príncipe: 1
# St. Martin: 1
# Samoa: 1
# St. Pierre & Miquelon: 1
# Anguilla: 1
# American Samoa: 1
# Åland Islands: 1
# St. Barthélemy: 1

# %% [markdown]
# ### Region

# %%
# Get the value counts for the 'country' column
region_counts = df['region'].value_counts()

# Iterate through the Series and print each country with its count
for region, count in region_counts.items():
    print(f"{region}: {count}")
# Out:
# not available in demo dataset: 508211
# California: 107494
# New York: 26431
# (not set): 26384
# England: 13198
# Texas: 8749
# Bangkok: 7709
# Washington: 7642
# Illinois: 7585
# Ho Chi Minh: 7250
# Istanbul: 6330
# Maharashtra: 6184
# Ontario: 5997
# Taipei City: 5788
# Karnataka: 5476
# Delhi: 5278
# Hanoi: 5141
# New South Wales: 4932
# Tamil Nadu: 4632
# Ile-de-France: 4338
# State of Sao Paulo: 4189
# Telangana: 3955
# County Dublin: 3650
# Tel Aviv District: 3633
# Tokyo: 3341
# Jakarta: 3338
# Masovian Voivodeship: 3288
# Virginia: 3101
# Community of Madrid: 2937
# Victoria: 2741
# Massachusetts: 2640
# Quebec: 2585
# Michigan: 2578
# Mexico City: 2556
# District of Columbia: 2532
# Georgia: 2476
# Seoul: 2380
# Federal Territory of Kuala Lumpur: 2234
# Metro Manila: 2192
# Moscow: 2151
# Pennsylvania: 1846
# West Bengal: 1840
# Lima Region: 1794
# Bogota: 1635
# North Holland: 1544
# Ankara: 1511
# Bucharest: 1431
# Catalonia: 1427
# Kyiv city: 1339
# Izmir: 1321
# Oregon: 1319
# Berlin: 1244
# Lombardy: 1235
# Buenos Aires: 1226
# Dublin City: 1220
# Zurich: 1186
# New Taipei City: 1135
# Stockholm County: 1120
# Dubai: 1064
# Dhaka Division: 985
# Gujarat: 928
# Colorado: 893
# Queensland: 857
# Dong Nai: 853
# Hamburg: 837
# Chon Buri: 779
# Osaka Prefecture: 752
# Attica: 696
# Khon Kaen: 682
# Ohio: 654
# Da Nang: 647
# British Columbia: 643
# Riyadh Province: 637
# Chiang Mai: 635
# State of Rio de Janeiro: 635
# Vienna: 622
# North Carolina: 616
# Prague: 604
# Florida: 596
# Bavaria: 585
# New Jersey: 563
# Arizona: 544
# Wisconsin: 543
# Haryana: 543
# Budapest: 540
# Lazio: 517
# Central Visayas: 507
# Haiphong: 480
# Vastra Gotaland County: 456
# Taichung City: 430
# Santiago Metropolitan Region: 422
# Lisbon: 415
# Sindh: 415
# Makkah Province: 407
# Hesse: 396
# West Java: 385
# Sofia City Province: 378
# Bursa: 378
# Lesser Poland Voivodeship: 348
# Kanagawa Prefecture: 325
# Nakhon Pathom: 312
# Nakhon Ratchasima: 309
# Auckland: 306
# Thai Nguyen: 300
# Western Province: 291
# Punjab: 284
# Lagos: 277
# Nevada: 274
# Madhya Pradesh: 273
# State of Minas Gerais: 267
# Provence-Alpes-Cote d'Azur: 264
# Selangor: 261
# Taoyuan County: 255
# Alberta: 254
# Nakhon Sawan: 253
# City of Zagreb: 247
# East Java: 244
# Uttar Pradesh: 242
# Nuevo Leon: 240
# Zulia: 239
# Kaohsiung City: 236
# Hauts-de-France: 236
# Saint Petersburg: 233
# Rajasthan: 231
# Antalya: 231
# Brussels: 228
# Minnesota: 212
# Tennessee: 209
# Zhejiang: 205
# Tbilisi: 205
# Surat Thani: 202
# Greater Poland Voivodeship: 196
# Adana: 188
# Songkhla: 182
# Federal District: 177
# Auvergne-Rhone-Alpes: 174
# Andalusia: 170
# Santa Fe Province: 164
# Udon Thani: 163
# Bac Ninh Province: 160
# Basque Country: 157
# Djak Lak Province: 157
# Grand Casablanca: 149
# Ba Ria - Vung Tau: 145
# Hai Duong: 142
# Antioquia: 140
# County Cork: 137
# Perak: 133
# South Holland: 129
# Missouri: 129
# Capital Region of Denmark: 129
# State of Parana: 126
# Lower Silesian Voivodeship: 126
# Flanders: 124
# Amman Governorate: 123
# North Rhine-Westphalia: 115
# Lam Djong: 109
# Utrecht: 108
# Western Australia: 107
# Chandigarh: 106
# Oslo: 103
# Cluj County: 103
# Khanh Hoa Province: 101
# State of Rio Grande do Sul: 97
# Iowa: 95
# Abu Dhabi: 95
# Konya: 95
# Cairo Governorate: 94
# Tien Giang: 92
# Ho Chi Minh City: 92
# Nghe An: 90
# Rayong: 90
# Can Tho: 87
# Scotland: 86
# Valencian Community: 85
# State of Goias: 75
# Shanghai: 72
# Kentucky: 70
# Kansas: 68
# South Carolina: 68
# Aquitaine: 68
# Mersin Province: 68
# Baden-Wurttemberg: 67
# Bratislava Region: 66
# Phuket: 64
# Thua Thien Hue: 64
# Region Syddanmark: 63
# Kerala: 62
# Utah: 62
# Nouvelle-Aquitaine: 62
# Idaho: 62
# Connecticut: 61
# North Brabant: 58
# Riga: 58
# Bihar: 57
# Saraburi: 55
# Brittany: 55
# Indiana: 55
# Thai Binh: 53
# Timis County: 53
# Alexandria Governorate: 52
# Davao Region: 51
# Castile-La Mancha: 50
# Cusco: 50
# Chiang Rai: 49
# Ubon Ratchathani: 48
# Piedmont: 48
# Beijing: 46
# Algiers Province: 46
# Pathum Thani: 45
# Maryland: 45
# Aragon: 43
# Western Cape: 43
# Nam Dinh: 43
# Fukui Prefecture: 43
# Kharkiv Oblast: 42
# Vilnius County: 42
# State of Bahia: 42
# South Moravian Region: 42
# Valle del Cauca: 42
# Cordoba: 42
# North Denmark Region: 41
# Quang Nam Province: 41
# Binh Dinh Province: 41
# Vinh Phuc Province: 41
# Kayseri Province: 39
# Campania: 39
# Sharjah: 38
# Geneva: 35
# Brest Region: 34
# Nebraska: 34
# Central Macedonia: 34
# Hsinchu County: 33
# Almaty Province: 33
# Prachuap Khiri Khan: 33
# Silesian Voivodeship: 33
# Odisha: 32
# Bac Giang: 30
# Chiayi County: 30
# Lower Austria: 30
# Samsun: 29
# Salzburg: 29
# Emilia-Romagna: 28
# Minsk Region: 28
# Phra Nakhon Si Ayutthaya: 27
# Kien Giang: 26
# Osijek-Baranja County: 26
# State of Ceara: 25
# Trabzon: 25
# Odessa Oblast: 25
# Hung Yen Province: 25
# West Pomeranian Voivodeship: 25
# Veneto: 25
# Dnipropetrovsk Oblast: 24
# Bihor County: 24
# Gaziantep: 24
# Harju County: 23
# Region Zealand: 23
# Hokkaido: 22
# Asturias: 22
# Quintana Roo: 22
# Hawaii: 21
# Buenos Aires Province: 21
# Alba County: 21
# North Sumatra: 20
# Sinaloa: 20
# Pingtung County: 20
# Wales: 20
# Jalisco: 20
# Johor: 20
# Phitsanulok: 20
# Tuscany: 20
# State of Mexico: 20
# Capital District: 19
# Sardinia: 19
# Tainan City: 19
# Wellington: 19
# Vladimir Oblast: 18
# South Australia: 18
# Grand Est: 18
# Doha: 18
# Nairobi County: 18
# Pays de la Loire: 18
# Pichincha: 17
# Vaud: 17
# Arequipa: 17
# Aust-Agder: 17
# Kosice Region: 16
# Guatemala Department: 16
# Gauteng: 15
# State of Amazonas: 15
# Panama: 15
# Mures County: 14
# West Virginia: 14
# Changhua County: 14
# Miaoli County: 14
# Hunedoara County: 14
# Thanh Hoa: 13
# Lampang: 13
# Iasi County: 13
# Piura: 13
# Tay Ninh Province: 13
# Djong Thap Province: 12
# Center District: 12
# Sakon Nakhon: 12
# Sibiu: 12
# La Libertad: 12
# Gia Lai Province: 12
# Quang Ngai: 12
# Olomouc Region: 12
# Miyazaki Prefecture: 11
# Magdalena: 11
# South Sulawesi: 11
# County Louth: 10
# Primorsky Krai: 10
# Newfoundland and Labrador: 10
# Faro District: 10
# State of Santa Catarina: 9
# Al Madinah Province: 9
# Podkarpackie Voivodeship: 9
# Gyeonggi-do: 9
# Prince Edward Island: 8
# Aichi Prefecture: 8
# Atlantico: 8
# KwaZulu-Natal: 8
# Ljubljana: 8
# Nagano Prefecture: 8
# Daegu: 8
# State of Pernambuco: 8
# Nakhon Si Thammarat: 7
# Groningen: 7
# Special Region of Yogyakarta: 7
# Guangdong: 7
# Binh Thuan Province: 7
# Central Denmark Region: 7
# Valparaiso Region: 7
# Phnom Penh: 7
# State of Mato Grosso: 7
# Usti nad Labem Region: 7
# County Wicklow: 7
# Moravian-Silesian Region: 7
# Louisiana: 7
# Phu Tho Province: 6
# Erzurum: 6
# Oran Province: 6
# Aydin Province: 6
# Baja California: 6
# Central Java: 6
# Bremen: 6
# Binh Phuoc: 6
# Overijssel: 6
# Rhone-Alpes: 6
# Ha Tinh Province: 6
# Eskisehir Province: 6
# Manitoba: 6
# Oklahoma: 6
# Hradec Kralove Region: 6
# Guanajuato: 6
# Beirut Governorate: 6
# Nord-Pas-de-Calais: 6
# Puebla: 6
# Gelderland: 6
# Sonora: 6
# Lopburi: 6
# Lviv Oblast: 6
# Maha Sarakham: 6
# Islamabad Capital Territory: 6
# Queretaro: 6
# State of Espirito Santo: 6
# Abruzzo: 6
# Okinawa Prefecture: 6
# Leiria District: 6
# Assam: 6
# Kumamoto Prefecture: 5
# San Salvador Department: 5
# Montana: 3

# %% [markdown]
# Droping the Rows for Region:
#
# not available in demo dataset: 508211
#
# (not set): 26384

# %%
df_checkpoint = df.copy()

# Drop rows where 'region' is "(not set)" or "not available in demo dataset"
df = df[~df['region'].isin(["(not set)", "not available in demo dataset"])]

# Verify the changes by checking the counts again (optional)
print(df['region'].value_counts(dropna=False))
# Out:
# California                 107494
# New York                    26431
# England                     13198
# Texas                        8749
# Bangkok                      7709
#                             ...
# Abruzzo                         6
# Lviv Oblast                     6
# Kumamoto Prefecture             5
# San Salvador Department         5
# Montana                         3
# Name: region, Length: 374, dtype: int64

# %% [markdown]
# ### Metro

# %%
# Get the value counts for the 'country' column
metro_counts = df['metro'].value_counts()

# Iterate through the Series and print each country with its count
for metro, count in metro_counts.items():
    print(f"{metro}: {count}")
# Out:
# (not set): 173935
# San Francisco-Oakland-San Jose CA: 95912
# New York NY: 26915
# London: 12571
# Los Angeles CA: 9995
# Seattle-Tacoma WA: 7642
# Chicago IL: 7585
# Austin TX: 3790
# Washington DC (Hagerstown MD): 3380
# Boston MA-Manchester NH: 2628
# Houston TX: 2475
# Atlanta GA: 2463
# Detroit MI: 2403
# Roanoke-Lynchburg VA: 2227
# Dallas-Ft. Worth TX: 2012
# San Diego CA: 1364
# Portland OR: 1319
# Pittsburgh PA: 1076
# Denver CO: 877
# Philadelphia PA: 800
# Phoenix AZ: 537
# Charlotte NC: 525
# Columbus OH: 517
# La Crosse-Eau Claire WI: 396
# San Antonio TX: 393
# Orlando-Daytona Beach-Melbourne FL: 360
# JP_KANTO: 279
# North West: 271
# Minneapolis-St. Paul MN: 197
# Nashville TN: 191
# Miami-Ft. Lauderdale FL: 161
# Midlands: 131
# Omaha NE: 129
# Grand Rapids-Kalamazoo-Battle Creek MI: 128
# Kansas City MO: 117
# Yorkshire: 94
# Chico-Redding CA: 94
# Green Bay-Appleton WI: 91
# Meridian (exc. Channel Islands): 89
# Las Vegas NV: 76
# Cincinnati OH: 71
# Fresno-Visalia CA: 67
# Cleveland-Akron (Canton) OH: 66
# Central Scotland: 65
# Louisville KY: 62
# Sacramento-Stockton-Modesto CA: 62
# Salt Lake City UT: 62
# Hartford & New Haven CT: 61
# Idaho Falls-Pocatello ID: 59
# Raleigh-Durham (Fayetteville) NC: 55
# Indianapolis IN: 55
# Charleston SC: 52
# Tulsa OK: 51
# Lansing MI: 47
# Milwaukee WI: 39
# Harlingen-Weslaco-Brownsville-McAllen TX: 36
# Tampa-St. Petersburg (Sarasota) FL: 34
# El Paso TX: 33
# Baltimore MD: 32
# St. Louis MO: 27
# Jacksonville FL: 27
# JP_KINKI: 26
# Norfolk-Portsmouth-Newport News VA: 26
# Utica NY: 23
# North Scotland: 21
# Honolulu HI: 21
# HTV Wales: 20
# Albany-Schenectady-Troy NY: 19
# Madison WI: 17
# Greenville-Spartanburg-Asheville-Anderson: 16
# Colorado Springs-Pueblo CO: 16
# Wheeling WV-Steubenville OH: 14
# Charlottesville VA: 13
# HTV West: 13
# JP_OTHER: 12
# Memphis TN: 10
# Abilene-Sweetwater TX: 10
# Mankato MN: 9
# Lexington KY: 8
# Panama City FL: 8
# Springfield MO: 8
# Tri-Cities TN-VA: 8
# Syracuse NY: 7
# Tucson (Sierra Vista) AZ: 7
# Augusta GA: 7
# New Orleans LA: 7
# Tallahassee FL-Thomasville GA: 6
# Rochester-Mason City-Austin,IA: 6
# Chattanooga TN: 6
# Springfield-Holyoke MA: 6
# Providence-New Bedford,MA: 6
# Boise ID: 3
# Butte-Bozeman MT: 3

# %%
# Drop rows where 'metro' is "(not set)"
df = df[df['metro'] != "(not set)"]

# Verify the changes by checking the counts again (optional)
print(df['metro'].value_counts(dropna=False))
# Out:
# San Francisco-Oakland-San Jose CA    95912
# New York NY                          26915
# London                               12571
# Los Angeles CA                        9995
# Seattle-Tacoma WA                     7642
#                                      ...
# Rochester-Mason City-Austin,IA           6
# Springfield-Holyoke MA                   6
# Chattanooga TN                           6
# Boise ID                                 3
# Butte-Bozeman MT                         3
# Name: metro, Length: 92, dtype: int64

# %% [markdown]
# ### City

# %%
# Get the value counts for the 'country' column
city_counts = df['city'].value_counts()

# Iterate through the Series and print each country with its count
for city, count in city_counts.items():
    print(f"{city}: {count}")
# Out:
# Mountain View: 40884
# New York: 26369
# San Francisco: 20328
# Sunnyvale: 13086
# London: 12443
# San Jose: 10295
# Los Angeles: 8670
# Chicago: 7444
# Seattle: 5025
# Austin: 3790
# Santa Clara: 3183
# Palo Alto: 2886
# Washington: 2532
# Houston: 2475
# Atlanta: 2352
# Ann Arbor: 2241
# Salem: 2227
# Kirkland: 1974
# Dallas: 1834
# San Bruno: 1686
# Cambridge: 1585
# San Diego: 1336
# Pittsburgh: 1076
# Fremont: 974
# Boston: 967
# Irvine: 954
# Boardman: 852
# Ashburn: 828
# Philadelphia: 744
# Cupertino: 667
# Milpitas: 605
# Redmond: 551
# Columbus: 517
# Charlotte: 510
# Boulder: 462
# Phoenix: 421
# Denver: 396
# Eau Claire: 396
# San Antonio: 393
# Oakland: 342
# San Mateo: 341
# Redwood City: 299
# Jersey City: 256
# Portland: 247
# Orlando: 242
# Laguna Beach: 225
# Minato: 216
# Nashville: 185
# Manchester: 184
# Lake Oswego: 183
# Minneapolis: 180
# Piscataway Township: 165
# Miami: 155
# Detroit: 130
# Evanston: 125
# Kalamazoo: 120
# Oviedo: 118
# Tempe: 116
# Kansas City: 100
# Council Bluffs: 95
# Chico: 94
# South San Francisco: 88
# Egham: 78
# Leeds: 76
# Ridgewood: 75
# Oshkosh: 72
# Las Vegas: 69
# Menlo Park: 67
# Akron: 66
# Cincinnati: 65
# Glasgow: 65
# Canterbury: 63
# Louisville: 62
# Oxford: 62
# Sacramento: 62
# University Park: 61
# Wellesley: 60
# Fresno: 59
# Rexburg: 59
# Richardson: 58
# Indianapolis: 55
# Raleigh: 55
# Goose Creek: 52
# Birmingham: 51
# Liverpool: 46
# Berkeley: 46
# Coffeyville: 45
# Molesey: 44
# Avon: 38
# Santa Monica: 38
# McAllen: 36
# Smyrna: 35
# Salt Lake City: 35
# East Lansing: 35
# Omaha: 34
# Tampa: 34
# Salford: 33
# Bothell: 33
# El Paso: 33
# Whitewater: 32
# Shinjuku: 31
# Bellevue: 30
# Bellingham: 29
# San Marcos: 28
# Jacksonville: 27
# Plano: 27
# Osaka: 26
# Norfolk: 26
# Camden: 24
# Stanford: 24
# Hamden: 23
# Oneonta: 23
# Westlake Village: 23
# Yokohama: 22
# Bellflower: 22
# Aberdeen: 21
# Honolulu: 21
# Collegeville: 20
# Pleasanton: 20
# Newtonville: 19
# Tigard: 19
# Hayward: 19
# Chamblee: 18
# The Dalles: 18
# Overland Park: 17
# Madison: 17
# Bournemouth: 17
# Dahlonega: 17
# Saint Paul: 17
# Pueblo: 16
# Greer: 16
# Wheaton: 16
# Danville: 16
# Farmington Hills: 16
# Lehi: 15
# Lenoir: 15
# Santa Ana: 15
# Riverside: 15
# Wheeling: 14
# Nottingham: 14
# Altrincham: 14
# St. Louis: 14
# Rockwood: 14
# Charlottesville: 13
# Normandy: 13
# College Park: 13
# Appleton: 12
# Okemos: 12
# Forest Park: 12
# Fort Worth: 12
# Woodbridge Township: 12
# Thornton: 12
# Sakai: 12
# Druid Hills: 12
# Edison: 11
# Cardiff: 11
# Chino: 11
# North Richland Hills: 11
# Memphis: 10
# Saratoga: 10
# Burlington: 10
# Shibuya: 10
# Ballinger: 10
# Mankato: 9
# Fareham: 9
# Lewisville: 9
# Wrexham: 9
# San Carlos: 9
# Dundalk: 9
# Atwater: 8
# Allendale Charter Township: 8
# Walnut Creek: 8
# Towson: 8
# Panama City: 8
# Parsippany-Troy Hills: 8
# Baltimore: 8
# Anaheim: 8
# Lexington: 8
# Springfield: 8
# Johnson City: 8
# Milwaukee: 7
# Tucson: 7
# Culpeper: 7
# Union City: 7
# Paradise: 7
# White Plains: 7
# Redondo Beach: 7
# Shiocton: 7
# Evans: 7
# Fort Collins: 7
# Bath: 7
# Syracuse: 7
# Dublin: 7
# Columbia: 7
# New Orleans: 7
# South El Monte: 7
# Marlboro: 6
# Lincoln: 6
# Lawrence Township: 6
# Watford: 6
# Sandy: 6
# Amherst: 6
# Sandy Springs: 6
# Telford: 6
# Bristol: 6
# Newark: 6
# Sheffield: 6
# Brookline: 6
# Villanova: 6
# Carrollton: 6
# North Attleborough: 6
# Orem: 6
# Tallahassee: 6
# Los Gatos: 6
# LaFayette: 6
# Pryor: 6
# Byron: 6
# Barnsley: 6
# Miami Beach: 6
# Coventry: 6
# Campbell: 5
# Douglasville: 5
# Daly City: 4
# Boise: 3
# Bozeman: 3

# %% [markdown]
# ### Reviewing Value Counts After Geographical Cleaning

# %%
# Iterate over all column names in the DataFrame
for column in df.columns:
    print(f"Value counts for {column}:")
    print(df[column].value_counts(dropna=False))  # Include NaN counts
    print("\n")  # Adds a newline for better readability between columns
# Out:
# Value counts for channelGrouping:
# Organic Search    68242
# Referral          61065
# Direct            41739
# Social             9016
# Paid Search        8021
# Display            3850
# Affiliates         1660
# (Other)              62
# Name: channelGrouping, dtype: int64
#
#
# Value counts for date:
# 2017-05-16    1396
# 2016-12-19    1349
# 2016-10-04    1175
# 2016-12-12    1170
# 2017-04-26    1164
#               ...
# 2017-05-06     170
# 2017-02-12     170
# 2017-01-14     169
# 2016-08-13     167
# 2016-10-01     146
# Name: date, Length: 366, dtype: int64
#
#
# Value counts for fullVisitorId:
# 824839726118485274     230
# 7634897085866546110    126
# 949718915643445721     107
# 6254908847172458133    101
# 9609104828919391966     98
#                       ...
# 6254351152298198797      1
# 7272597777661582423      1
# 6147754833880070280      1
# 2027231394825948882      1
# 2035095632074835075      1
# Name: fullVisitorId, Length: 128969, dtype: int64
#
#
# Value counts for sessionId:
# 7088163533987137698_1488441216    2
# 5643319853745503187_1481874929    2
# 6008852899645973932_1486281026    2
# 6667424077677299781_1498631774    2
# 7483600664917507409_1476512865    2
#                                  ..
# 5456301402188625337_1473823243    1
# 6543538822610256700_1473790544    1
# 0179973609749142108_1473786146    1
# 8243678505312262823_1473793150    1
# 2035095632074835075_1483570454    1
# Name: sessionId, Length: 193475, dtype: int64
#
#
# Value counts for socialEngagementType:
# Not Socially Engaged    193655
# Name: socialEngagementType, dtype: int64
#
#
# Value counts for visitId:
# 1484649802    6
# 1479668456    4
# 1475719086    4
# 1488904421    4
# 1484649800    4
#              ..
# 1473764336    1
# 1473833130    1
# 1473819963    1
# 1473806736    1
# 1483570454    1
# Name: visitId, Length: 192162, dtype: int64
#
#
# Value counts for visitNumber:
# 1      117674
# 2       30417
# 3       13913
# 4        8159
# 5        5187
#         ...
# 303         1
# 302         1
# 266         1
# 265         1
# 377         1
# Name: visitNumber, Length: 355, dtype: int64
#
#
# Value counts for visitStartTime:
# 1484649802    6
# 1479668456    4
# 1488904421    4
# 1475719086    4
# 1484649800    4
#              ..
# 1473783256    1
# 1473796227    1
# 1473802600    1
# 1473795333    1
# 1483570454    1
# Name: visitStartTime, Length: 192340, dtype: int64
#
#
# Value counts for continent:
# Americas    179568
# Europe       13425
# Asia           624
# Oceania         31
# Africa           7
# Name: continent, dtype: int64
#
#
# Value counts for subContinent:
# Northern America      179494
# Northern Europe        13230
# Eastern Asia             466
# Western Europe           132
# Southern Asia             77
# Southeast Asia            46
# Southern Europe           44
# Central America           41
# Western Asia              35
# Australasia               30
# South America             28
# Eastern Europe            19
# Caribbean                  5
# Southern Africa            4
# Western Africa             2
# Eastern Africa             1
# Micronesian Region         1
# Name: subContinent, dtype: int64
#
#
# Value counts for country:
# United States         179336
# United Kingdom         13163
# Japan                    352
# Canada                   158
# India                     75
#                        ...
# Dominican Republic         1
# Guam                       1
# Kenya                      1
# Austria                    1
# Lebanon                    1
# Name: country, Length: 64, dtype: int64
#
#
# Value counts for region:
# California              107494
# New York                 26431
# England                  13169
# Texas                     8749
# Washington                7642
# Illinois                  7585
# Virginia                  3101
# Massachusetts             2640
# Michigan                  2578
# District of Columbia      2532
# Georgia                   2476
# Pennsylvania              1846
# Oregon                    1319
# Colorado                   893
# Ohio                       654
# Florida                    596
# North Carolina             580
# New Jersey                 563
# Arizona                    544
# Wisconsin                  543
# Tokyo                      257
# Minnesota                  212
# Tennessee                  209
# Missouri                   129
# Iowa                        95
# Scotland                    86
# Nevada                      76
# Kentucky                    70
# Kansas                      68
# South Carolina              68
# Idaho                       62
# Utah                        62
# Connecticut                 61
# Indiana                     55
# Maryland                    45
# Nebraska                    34
# Osaka Prefecture            26
# Kanagawa Prefecture         22
# Hawaii                      21
# Wales                       20
# West Virginia               14
# Fukui Prefecture            12
# Louisiana                    7
# Oklahoma                     6
# Montana                      3
# Name: region, dtype: int64
#
#
# Value counts for metro:
# San Francisco-Oakland-San Jose CA    95912
# New York NY                          26915
# London                               12571
# Los Angeles CA                        9995
# Seattle-Tacoma WA                     7642
#                                      ...
# Rochester-Mason City-Austin,IA           6
# Springfield-Holyoke MA                   6
# Chattanooga TN                           6
# Boise ID                                 3
# Butte-Bozeman MT                         3
# Name: metro, Length: 92, dtype: int64
#
#
# Value counts for city:
# Mountain View    40884
# New York         26369
# San Francisco    20328
# Sunnyvale        13086
# London           12443
#                  ...
# Campbell             5
# Douglasville         5
# Daly City            4
# Boise                3
# Bozeman              3
# Name: city, Length: 225, dtype: int64
#
#
# Value counts for cityId:
# not available in demo dataset    193655
# Name: cityId, dtype: int64
#
#
# Value counts for networkDomain:
# (not set)              115802
# comcast.net             12970
# unknown.unknown          9151
# comcastbusiness.net      4718
# rr.com                   4531
#                         ...
# fullers.co.uk               1
# gadago.com                  1
# seidlerchem.com             1
# atavia.com                  1
# northshore.org              1
# Name: networkDomain, Length: 3049, dtype: int64
#
#
# Value counts for latitude:
# not available in demo dataset    193655
# Name: latitude, dtype: int64
#
#
# Value counts for longitude:
# not available in demo dataset    193655
# Name: longitude, dtype: int64
#
#
# Value counts for networkLocation:
# not available in demo dataset    193655
# Name: networkLocation, dtype: int64
#
#
# Value counts for browser:
# Chrome                      157763
# Safari                       25946
# Firefox                       2924
# Internet Explorer             2294
# Safari (in-app)               1381
# Opera                         1212
# Edge                          1209
# Android Webview                560
# YaBrowser                      122
# Amazon Silk                     59
# UC Browser                      27
# Opera Mini                      26
# Android Browser                 23
# Coc Coc                         22
# Iron                            18
# Mozilla Compatible Agent        16
# BlackBerry                      13
# Maxthon                         10
# MRCHROME                         7
# Apple-iPhone7C2                  7
# Nichrome                         4
# Nintendo Browser                 3
# Mozilla                          2
# no-ua                            2
# (not set)                        1
# Changa 99695759                  1
# 0                                1
# YE                               1
# Puffin                           1
# Name: browser, dtype: int64
#
#
# Value counts for browserVersion:
# not available in demo dataset    193655
# Name: browserVersion, dtype: int64
#
#
# Value counts for browserSize:
# not available in demo dataset    193655
# Name: browserSize, dtype: int64
#
#
# Value counts for operatingSystem:
# Macintosh        84006
# Windows          33485
# iOS              26169
# Linux            19889
# Android          19824
# Chrome OS        10161
# Windows Phone       62
# (not set)           37
# BlackBerry          14
# Xbox                 3
# Nintendo WiiU        2
# Nintendo Wii         1
# FreeBSD              1
# Samsung              1
# Name: operatingSystem, dtype: int64
#
#
# Value counts for operatingSystemVersion:
# not available in demo dataset    193655
# Name: operatingSystemVersion, dtype: int64
#
#
# Value counts for isMobile:
# False    147424
# True      46231
# Name: isMobile, dtype: int64
#
#
# Value counts for mobileDeviceBranding:
# not available in demo dataset    193655
# Name: mobileDeviceBranding, dtype: int64
#
#
# Value counts for mobileDeviceModel:
# not available in demo dataset    193655
# Name: mobileDeviceModel, dtype: int64
#
#
# Value counts for mobileInputSelector:
# not available in demo dataset    193655
# Name: mobileInputSelector, dtype: int64
#
#
# Value counts for mobileDeviceInfo:
# not available in demo dataset    193655
# Name: mobileDeviceInfo, dtype: int64
#
#
# Value counts for mobileDeviceMarketingName:
# not available in demo dataset    193655
# Name: mobileDeviceMarketingName, dtype: int64
#
#
# Value counts for flashVersion:
# not available in demo dataset    193655
# Name: flashVersion, dtype: int64
#
#
# Value counts for language:
# not available in demo dataset    193655
# Name: language, dtype: int64
#
#
# Value counts for screenColors:
# not available in demo dataset    193655
# Name: screenColors, dtype: int64
#
#
# Value counts for screenResolution:
# not available in demo dataset    193655
# Name: screenResolution, dtype: int64
#
#
# Value counts for deviceCategory:
# desktop    147429
# mobile      42773
# tablet       3453
# Name: deviceCategory, dtype: int64
#
#
# Value counts for visits:
# 1    193655
# Name: visits, dtype: int64
#
#
# Value counts for hits:
# 1      62499
# 2      25291
# 3      19155
# 4      13580
# 5      10227
#        ...
# 301        1
# 192        1
# 259        1
# 286        1
# 308        1
# Name: hits, Length: 210, dtype: int64
#
#
# Value counts for pageviews:
# 1.0      63638
# 2.0      26847
# 3.0      20624
# 4.0      14772
# 5.0      11313
#          ...
# 270.0        1
# 193.0        1
# 162.0        1
# 137.0        1
# 98.0         1
# Name: pageviews, Length: 156, dtype: int64
#
#
# Value counts for bounces:
# NaN    130626
# 1.0     63029
# Name: bounces, dtype: int64
#
#
# Value counts for newVisits:
# 1.0    117674
# NaN     75981
# Name: newVisits, dtype: int64
#
#
# Value counts for transactionRevenue:
# NaN            186989
# 33590000.0        160
# 44790000.0        132
# 13590000.0        104
# 16990000.0         76
#                 ...
# 491400000.0         1
# 104340000.0         1
# 410980000.0         1
# 339660000.0         1
# 69390000.0          1
# Name: transactionRevenue, Length: 3494, dtype: int64
#
#
# Value counts for campaign:
# (not set)                                          184489
# AW - Dynamic Search Ads Whole Site                   5080
# AW - Accessories                                     2362
# Data Share Promo                                     1660
# test-liyuhz                                            22
# AW - Electronics                                       18
# Retail (DO NOT EDIT owners nophakun and tianyu)        12
# AW - Apparel                                            8
# All Products                                            3
# Data Share                                              1
# Name: campaign, dtype: int64
#
#
# Value counts for source:
# google                                               76193
# mall.googleplex.com                                  52205
# (direct)                                             41740
# youtube.com                                           6138
# dfa                                                   3315
#                                                      ...
# login.corp.google.com                                    1
# plusapp-autopush.corp.google.com                         1
# 0.shared.bow.cat2.ads-bow.qk.borg.google.com:9819        1
# vk.com                                                   1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898        1
# Name: source, Length: 211, dtype: int64
#
#
# Value counts for medium:
# referral     70081
# organic      68242
# (none)       41739
# cpc           8021
# cpm           3850
# affiliate     1660
# (not set)       62
# Name: medium, dtype: int64
#
#
# Value counts for keyword:
# NaN                                            119613
# (not provided)                                  65569
# 6qEhsCssdK0z36ri                                 4241
# google merchandise store                         1096
# 1hZbAqLCbjwfgOH7                                  707
#                                                 ...
# google store sell t shirt                           1
# google merchandise store mountain view hour         1
# google baseball hat                                 1
# google beenie                                       1
# google backback                                     1
# Name: keyword, Length: 259, dtype: int64
#
#
# Value counts for adwordsClickInfo.criteriaParameters:
# not available in demo dataset    193655
# Name: adwordsClickInfo.criteriaParameters, dtype: int64
#
#
# Value counts for isTrueDirect:
# NaN     102781
# True     90874
# Name: isTrueDirect, dtype: int64
#
#
# Value counts for referralPath:
# NaN                                                                                   123574
# /                                                                                      54082
# /yt/about/                                                                              4596
# /analytics/web/                                                                         1540
# /a/google.com/googletopia/discounts-deals-and-free-stuff/alphabet-google-discounts       814
#                                                                                        ...
# /ads/richmedia/studio/pv2/45589035/dirty/index.html                                        1
# /a/google.com/nestlabs/facilities/building-maps                                            1
# /ads/richmedia/studio/pv2/45589029/20160922141342673/index.html                            1
# /intl/ta/yt/about/                                                                         1
# /mail/mu/mp/509/                                                                           1
# Name: referralPath, Length: 718, dtype: int64
#
#
# Value counts for adwordsClickInfo.page:
# NaN     186184
# 1.0       7443
# 2.0         21
# 5.0          3
# 14.0         1
# 3.0          1
# 7.0          1
# 9.0          1
# Name: adwordsClickInfo.page, dtype: int64
#
#
# Value counts for adwordsClickInfo.slot:
# NaN    186184
# Top      7369
# RHS       102
# Name: adwordsClickInfo.slot, dtype: int64
#
#
# Value counts for adwordsClickInfo.gclId:
# NaN                                                                                           186161
# CJ6xtee6j9ACFQqDfgod8TkDNw                                                                        18
# Cj0KEQiAtqHEBRCNrdC6rYq9_oYBEiQAejvRlydKqhjz1oz3BhBTfMjjueAO4Cx4no5mJL6u3XbzFHAaAlL-8P8HAQ        17
# Cj0KEQiA6_TBBRDInaPjhcelt5oBEiQApPeTFwpkek9qjhpRwTa19k00tY0xRkHNiQRA3IOmKXsa9zQaAogR8P8HAQ        14
# Cj0KEQjwo-XIBRCOycL7hsuI_NoBEiQAuS6HtHOpolLDj1NmtFB8mNSxnWlOn2o79AL0iQ6yZUgark0aAqXK8P8HAQ        13
#                                                                                                ...
# CIbr3KTXt88CFdKIfgod3qoPyg                                                                         1
# COv9qKT6t88CFYpbhgodvt8B1Q                                                                         1
# CPLw5fyOuM8CFQ9EfgodrIUA7A                                                                         1
# CI6dsK36t88CFY9ZhgodqeAPFQ                                                                         1
# CjwKEAiA17LDBRDElqOGq8vR7m8SJAA1AC0_0wzbDX0fd-gzNVm4iuZRBFQ6id5RBK7XQZGOS1kIHRoCXJPw_wcB           1
# Name: adwordsClickInfo.gclId, Length: 6117, dtype: int64
#
#
# Value counts for adwordsClickInfo.adNetworkType:
# NaN                186184
# Google Search        7470
# Search partners         1
# Name: adwordsClickInfo.adNetworkType, dtype: int64
#
#
# Value counts for adwordsClickInfo.isVideoAd:
# NaN      186184
# False      7471
# Name: adwordsClickInfo.isVideoAd, dtype: int64
#
#
# Value counts for adContent:
# NaN                                            190740
# Google Merchandise Collection                    2029
# Google Online Store                               196
# Full auto ad IMAGE ONLY                           187
# Ad from 12/13/16                                  110
# Display Ad created 3/11/14                        109
# {KeyWord:Google Brand Items}                       28
# {KeyWord:Google Merchandise}                       27
# First Full Auto Template Test Ad                   24
# {KeyWord:Looking for Google Bags?}                 23
# Google Merchandise                                 22
# Display Ad created 3/11/15                         22
# Swag with Google Logos                             20
# Ad from 11/3/16                                    18
# 20% discount                                       16
# Display Ad created 11/17/14                        12
# {KeyWord:Google Drinkware}                         11
# {KeyWord:Google Branded Gear}                      10
# Ad from 11/7/16                                     8
# Full auto ad TEXT ONLY                              8
# {KeyWord:Want Google Stickers?}                     7
# {KeyWord:Google Men's T-Shirts}                     7
# JD_5a_v1                                            4
# {KeyWord:Google Branded Kit}                        3
# Official Google Merchandise - Fast Shipping         3
# {KeyWord:Want Google Pet Toys?}                     2
# free shipping                                       2
# Google Paraphernalia                                1
# Full auto ad NATIVE ONLY                            1
# {KeyWord:Google Branded Apparel}                    1
# LeEco_1a                                            1
# Google Store                                        1
# Swag w/ Google Logos                                1
# Free Shipping!                                      1
# Name: adContent, dtype: int64
#
#
# Value counts for campaignCode:
# NaN    193655
# Name: campaignCode, dtype: int64

# %%
print('The dimensions of the training dataset are:', df.shape)
# Out:
# The dimensions of the training dataset are: (193655, 55)

# %% [markdown]
# #### Data Cleaning Rationale
#
# Columns to Drop
#
# * Longitude and Latitude: All values are "not available in demo dataset." These columns do not provide any meaningful data for analysis.
# * NetworkLocation, BrowserVersion, OperatingSystemVersion, MobileDeviceBranding, MobileInputSelector, MobileDeviceModel, MobileDeviceInfo, MobileDeviceMarketingName, FlashVersion, Language, ScreenColors, ScreenResolution, BrowserSize: Similar to Longitude and Latitude, these columns are filled with "not available in demo dataset," making them redundant for any form of analysis.
# * Visits: This column has a constant value of 1 across all rows, offering no variation or useful information for analysis.
#
# Rows to Drop
# * Browser: There's one row with the value "(not set)" that does not contribute to meaningful analysis and can be removed for data consistency.
# * OperatingSystem: 37 rows are labeled as "(not set)", which are likely to introduce noise into any analysis or model training. Removing these will ensure more accurate results.
# * The decision to drop these specific columns and rows is guided by the principle of maintaining only relevant and informative data that contributes to the effectiveness of the analysis or machine learning models. Redundant or uninformative data can lead to skewed results, unnecessary complexity, and inefficiencies in processing and analysis.

# %%
df_checkpoint = df.copy()

# Drop specified columns
columns_to_drop = ['longitude', 'latitude', 'networkLocation', 'browserVersion',
                   'operatingSystemVersion', 'mobileDeviceBranding', 'mobileInputSelector',
                   'mobileDeviceModel', 'mobileDeviceInfo', 'mobileDeviceMarketingName',
                   'flashVersion', 'language', 'screenColors', 'screenResolution', 'browserSize',
                   'visits']
df.drop(columns=columns_to_drop, inplace=True)

# Drop rows where 'browser' is "(not set)"
df = df[df['browser'] != "(not set)"]

# Drop rows where 'operatingSystem' is "(not set)"
df = df[df['operatingSystem'] != "(not set)"]

# Ensure no other unwanted rows are present due to previous operations
print(df['browser'].value_counts(dropna=False))
print(df['operatingSystem'].value_counts(dropna=False))

# Display remaining columns for verification
print(df.columns)
# Out:
# Chrome                      157763
# Safari                       25946
# Firefox                       2924
# Internet Explorer             2294
# Safari (in-app)               1381
# Opera                         1212
# Edge                          1208
# Android Webview                560
# YaBrowser                      122
# Amazon Silk                     59
# UC Browser                      27
# Android Browser                 23
# Coc Coc                         22
# Iron                            18
# Opera Mini                      14
# BlackBerry                      13
# Maxthon                         10
# MRCHROME                         7
# Nichrome                         4
# Nintendo Browser                 3
# Mozilla Compatible Agent         3
# Mozilla                          2
# YE                               1
# Puffin                           1
# Name: browser, dtype: int64
# Macintosh        84006
# Windows          33485
# iOS              26168
# Linux            19889
# Android          19824
# Chrome OS        10161
# Windows Phone       62
# BlackBerry          14
# Xbox                 3
# Nintendo WiiU        2
# Nintendo Wii         1
# FreeBSD              1
# Samsung              1
# Name: operatingSystem, dtype: int64
# Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'continent', 'subContinent', 'country', 'region', 'metro', 'city',
#        'cityId', 'networkDomain', 'browser', 'operatingSystem', 'isMobile',
#        'deviceCategory', 'hits', 'pageviews', 'bounces', 'newVisits',
#        'transactionRevenue', 'campaign', 'source', 'medium', 'keyword',
#        'adwordsClickInfo.criteriaParameters', 'isTrueDirect', 'referralPath',
#        'adwordsClickInfo.page', 'adwordsClickInfo.slot',
#        'adwordsClickInfo.gclId', 'adwordsClickInfo.adNetworkType',
#        'adwordsClickInfo.isVideoAd', 'adContent', 'campaignCode'],
#       dtype='object')

# %%
print('The dimensions of the training dataset are:', df.shape)
# Out:
# The dimensions of the training dataset are: (193617, 39)

# %%
# Iterate over all column names in the DataFrame
for column in df.columns:
    print(f"Value counts for {column}:")
    print(df[column].value_counts(dropna=False))  # Include NaN counts
    print("\n")  # Adds a newline for better readability between columns
# Out:
# Value counts for channelGrouping:
# Organic Search    68237
# Referral          61065
# Direct            41727
# Social             8996
# Paid Search        8021
# Display            3850
# Affiliates         1660
# (Other)              61
# Name: channelGrouping, dtype: int64
#
#
# Value counts for date:
# 2017-05-16    1396
# 2016-12-19    1349
# 2016-10-04    1175
# 2016-12-12    1170
# 2017-04-26    1164
#               ...
# 2017-05-06     170
# 2017-02-12     170
# 2017-01-14     169
# 2016-08-13     167
# 2016-10-01     146
# Name: date, Length: 366, dtype: int64
#
#
# Value counts for fullVisitorId:
# 824839726118485274     230
# 7634897085866546110    126
# 949718915643445721     107
# 6254908847172458133    101
# 9609104828919391966     98
#                       ...
# 2514418634771358752      1
# 560016838311060230       1
# 6254351152298198797      1
# 7272597777661582423      1
# 2035095632074835075      1
# Name: fullVisitorId, Length: 128937, dtype: int64
#
#
# Value counts for sessionId:
# 7088163533987137698_1488441216    2
# 5643319853745503187_1481874929    2
# 6667424077677299781_1498631774    2
# 9248188248183652052_1472453841    2
# 7483600664917507409_1476512865    2
#                                  ..
# 4578640586284138624_1473793915    1
# 8881859026571518968_1473811154    1
# 1616635312025969512_1473806638    1
# 5745691898696443704_1473787896    1
# 2035095632074835075_1483570454    1
# Name: sessionId, Length: 193437, dtype: int64
#
#
# Value counts for socialEngagementType:
# Not Socially Engaged    193617
# Name: socialEngagementType, dtype: int64
#
#
# Value counts for visitId:
# 1484649802    6
# 1479668456    4
# 1475719086    4
# 1488904421    4
# 1484649800    4
#              ..
# 1473809384    1
# 1473785522    1
# 1473774965    1
# 1473774937    1
# 1483570454    1
# Name: visitId, Length: 192129, dtype: int64
#
#
# Value counts for visitNumber:
# 1      117642
# 2       30415
# 3       13912
# 4        8158
# 5        5186
#         ...
# 303         1
# 302         1
# 266         1
# 265         1
# 377         1
# Name: visitNumber, Length: 355, dtype: int64
#
#
# Value counts for visitStartTime:
# 1484649802    6
# 1479668456    4
# 1488904421    4
# 1475719086    4
# 1484649800    4
#              ..
# 1473771208    1
# 1473816989    1
# 1473798894    1
# 1473799304    1
# 1483570454    1
# Name: visitStartTime, Length: 192307, dtype: int64
#
#
# Value counts for continent:
# Americas    179537
# Europe       13418
# Asia           624
# Oceania         31
# Africa           7
# Name: continent, dtype: int64
#
#
# Value counts for subContinent:
# Northern America      179463
# Northern Europe        13223
# Eastern Asia             466
# Western Europe           132
# Southern Asia             77
# Southeast Asia            46
# Southern Europe           44
# Central America           41
# Western Asia              35
# Australasia               30
# South America             28
# Eastern Europe            19
# Caribbean                  5
# Southern Africa            4
# Western Africa             2
# Eastern Africa             1
# Micronesian Region         1
# Name: subContinent, dtype: int64
#
#
# Value counts for country:
# United States         179305
# United Kingdom         13156
# Japan                    352
# Canada                   158
# India                     75
#                        ...
# Dominican Republic         1
# Guam                       1
# Kenya                      1
# Austria                    1
# Lebanon                    1
# Name: country, Length: 64, dtype: int64
#
#
# Value counts for region:
# California              107492
# New York                 26427
# England                  13162
# Texas                     8739
# Washington                7642
# Illinois                  7579
# Virginia                  3094
# Massachusetts             2640
# Michigan                  2578
# District of Columbia      2532
# Georgia                   2475
# Pennsylvania              1846
# Oregon                    1319
# Colorado                   893
# Ohio                       654
# Florida                    596
# North Carolina             580
# New Jersey                 563
# Arizona                    544
# Wisconsin                  543
# Tokyo                      257
# Minnesota                  211
# Tennessee                  209
# Missouri                   129
# Iowa                        95
# Scotland                    86
# Nevada                      76
# Kentucky                    70
# Kansas                      68
# South Carolina              68
# Idaho                       62
# Utah                        62
# Connecticut                 61
# Indiana                     55
# Maryland                    45
# Nebraska                    34
# Osaka Prefecture            26
# Kanagawa Prefecture         22
# Hawaii                      21
# Wales                       20
# West Virginia               14
# Fukui Prefecture            12
# Louisiana                    7
# Oklahoma                     6
# Montana                      3
# Name: region, dtype: int64
#
#
# Value counts for metro:
# San Francisco-Oakland-San Jose CA    95910
# New York NY                          26911
# London                               12564
# Los Angeles CA                        9995
# Seattle-Tacoma WA                     7642
#                                      ...
# Rochester-Mason City-Austin,IA           6
# Springfield-Holyoke MA                   6
# Chattanooga TN                           6
# Boise ID                                 3
# Butte-Bozeman MT                         3
# Name: metro, Length: 92, dtype: int64
#
#
# Value counts for city:
# Mountain View    40884
# New York         26365
# San Francisco    20326
# Sunnyvale        13086
# London           12436
#                  ...
# Campbell             5
# Douglasville         5
# Daly City            4
# Boise                3
# Bozeman              3
# Name: city, Length: 225, dtype: int64
#
#
# Value counts for cityId:
# not available in demo dataset    193617
# Name: cityId, dtype: int64
#
#
# Value counts for networkDomain:
# (not set)                 115800
# comcast.net                12968
# unknown.unknown             9146
# comcastbusiness.net         4718
# rr.com                      4531
#                            ...
# twowincolimited-hk.com         1
# doc.gov                        1
# aaminc.com                     1
# versaceus.com                  1
# northshore.org                 1
# Name: networkDomain, Length: 3048, dtype: int64
#
#
# Value counts for browser:
# Chrome                      157763
# Safari                       25946
# Firefox                       2924
# Internet Explorer             2294
# Safari (in-app)               1381
# Opera                         1212
# Edge                          1208
# Android Webview                560
# YaBrowser                      122
# Amazon Silk                     59
# UC Browser                      27
# Android Browser                 23
# Coc Coc                         22
# Iron                            18
# Opera Mini                      14
# BlackBerry                      13
# Maxthon                         10
# MRCHROME                         7
# Nichrome                         4
# Nintendo Browser                 3
# Mozilla Compatible Agent         3
# Mozilla                          2
# YE                               1
# Puffin                           1
# Name: browser, dtype: int64
#
#
# Value counts for operatingSystem:
# Macintosh        84006
# Windows          33485
# iOS              26168
# Linux            19889
# Android          19824
# Chrome OS        10161
# Windows Phone       62
# BlackBerry          14
# Xbox                 3
# Nintendo WiiU        2
# Nintendo Wii         1
# FreeBSD              1
# Samsung              1
# Name: operatingSystem, dtype: int64
#
#
# Value counts for isMobile:
# False    147399
# True      46218
# Name: isMobile, dtype: int64
#
#
# Value counts for deviceCategory:
# desktop    147404
# mobile      42760
# tablet       3453
# Name: deviceCategory, dtype: int64
#
#
# Value counts for hits:
# 1      62476
# 2      25285
# 3      19153
# 4      13577
# 5      10225
#        ...
# 301        1
# 192        1
# 259        1
# 286        1
# 308        1
# Name: hits, Length: 210, dtype: int64
#
#
# Value counts for pageviews:
# 1.0      63614
# 2.0      26841
# 3.0      20620
# 4.0      14771
# 5.0      11312
#          ...
# 270.0        1
# 193.0        1
# 162.0        1
# 137.0        1
# 98.0         1
# Name: pageviews, Length: 156, dtype: int64
#
#
# Value counts for bounces:
# NaN    130611
# 1.0     63006
# Name: bounces, dtype: int64
#
#
# Value counts for newVisits:
# 1.0    117642
# NaN     75975
# Name: newVisits, dtype: int64
#
#
# Value counts for transactionRevenue:
# NaN            186951
# 33590000.0        160
# 44790000.0        132
# 13590000.0        104
# 16990000.0         76
#                 ...
# 491400000.0         1
# 104340000.0         1
# 410980000.0         1
# 339660000.0         1
# 69390000.0          1
# Name: transactionRevenue, Length: 3494, dtype: int64
#
#
# Value counts for campaign:
# (not set)                                          184451
# AW - Dynamic Search Ads Whole Site                   5080
# AW - Accessories                                     2362
# Data Share Promo                                     1660
# test-liyuhz                                            22
# AW - Electronics                                       18
# Retail (DO NOT EDIT owners nophakun and tianyu)        12
# AW - Apparel                                            8
# All Products                                            3
# Data Share                                              1
# Name: campaign, dtype: int64
#
#
# Value counts for source:
# google                                               76188
# mall.googleplex.com                                  52205
# (direct)                                             41728
# youtube.com                                           6119
# dfa                                                   3315
#                                                      ...
# login.corp.google.com                                    1
# plusapp-autopush.corp.google.com                         1
# 0.shared.bow.cat2.ads-bow.qk.borg.google.com:9819        1
# vk.com                                                   1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898        1
# Name: source, Length: 211, dtype: int64
#
#
# Value counts for medium:
# referral     70061
# organic      68237
# (none)       41727
# cpc           8021
# cpm           3850
# affiliate     1660
# (not set)       61
# Name: medium, dtype: int64
#
#
# Value counts for keyword:
# NaN                           119580
# (not provided)                 65569
# 6qEhsCssdK0z36ri                4241
# google merchandise store        1096
# 1hZbAqLCbjwfgOH7                 707
#                                ...
# google notebooks                   1
# lava floor lamp                    1
# Youtube water bottle merch         1
# google store sell t shirt          1
# google backback                    1
# Name: keyword, Length: 257, dtype: int64
#
#
# Value counts for adwordsClickInfo.criteriaParameters:
# not available in demo dataset    193617
# Name: adwordsClickInfo.criteriaParameters, dtype: int64
#
#
# Value counts for isTrueDirect:
# NaN     102760
# True     90857
# Name: isTrueDirect, dtype: int64
#
#
# Value counts for referralPath:
# NaN                                                                                                                                                               123556
# /                                                                                                                                                                  54081
# /yt/about/                                                                                                                                                          4583
# /analytics/web/                                                                                                                                                     1540
# /a/google.com/googletopia/discounts-deals-and-free-stuff/alphabet-google-discounts                                                                                   814
#                                                                                                                                                                    ...
# /FG0oftTBYt                                                                                                                                                            1
# /ads/richmedia/studio/pv2/45678657/dirty/index.html                                                                                                                    1
# /a/google.com/nestlabs/the-nest-pulse                                                                                                                                  1
# /from=2001a/bd_page_type=1/ssid=0/uid=0/pu=usm%402%2Csz%401320_1001%2Cta%40iphone_2_6.0_3_537/baiduid=494FFE6533C49BB85AC76FCE5488FE5B/w=0_10_/t=iphone/l=3/tc         1
# /mail/mu/mp/509/                                                                                                                                                       1
# Name: referralPath, Length: 717, dtype: int64
#
#
# Value counts for adwordsClickInfo.page:
# NaN     186146
# 1.0       7443
# 2.0         21
# 5.0          3
# 14.0         1
# 3.0          1
# 7.0          1
# 9.0          1
# Name: adwordsClickInfo.page, dtype: int64
#
#
# Value counts for adwordsClickInfo.slot:
# NaN    186146
# Top      7369
# RHS       102
# Name: adwordsClickInfo.slot, dtype: int64
#
#
# Value counts for adwordsClickInfo.gclId:
# NaN                                                                                           186123
# CJ6xtee6j9ACFQqDfgod8TkDNw                                                                        18
# Cj0KEQiAtqHEBRCNrdC6rYq9_oYBEiQAejvRlydKqhjz1oz3BhBTfMjjueAO4Cx4no5mJL6u3XbzFHAaAlL-8P8HAQ        17
# Cj0KEQiA6_TBBRDInaPjhcelt5oBEiQApPeTFwpkek9qjhpRwTa19k00tY0xRkHNiQRA3IOmKXsa9zQaAogR8P8HAQ        14
# Cj0KEQjwo-XIBRCOycL7hsuI_NoBEiQAuS6HtHOpolLDj1NmtFB8mNSxnWlOn2o79AL0iQ6yZUgark0aAqXK8P8HAQ        13
#                                                                                                ...
# CIbr3KTXt88CFdKIfgod3qoPyg                                                                         1
# COv9qKT6t88CFYpbhgodvt8B1Q                                                                         1
# CPLw5fyOuM8CFQ9EfgodrIUA7A                                                                         1
# CI6dsK36t88CFY9ZhgodqeAPFQ                                                                         1
# CjwKEAiA17LDBRDElqOGq8vR7m8SJAA1AC0_0wzbDX0fd-gzNVm4iuZRBFQ6id5RBK7XQZGOS1kIHRoCXJPw_wcB           1
# Name: adwordsClickInfo.gclId, Length: 6117, dtype: int64
#
#
# Value counts for adwordsClickInfo.adNetworkType:
# NaN                186146
# Google Search        7470
# Search partners         1
# Name: adwordsClickInfo.adNetworkType, dtype: int64
#
#
# Value counts for adwordsClickInfo.isVideoAd:
# NaN      186146
# False      7471
# Name: adwordsClickInfo.isVideoAd, dtype: int64
#
#
# Value counts for adContent:
# NaN                                            190702
# Google Merchandise Collection                    2029
# Google Online Store                               196
# Full auto ad IMAGE ONLY                           187
# Ad from 12/13/16                                  110
# Display Ad created 3/11/14                        109
# {KeyWord:Google Brand Items}                       28
# {KeyWord:Google Merchandise}                       27
# First Full Auto Template Test Ad                   24
# {KeyWord:Looking for Google Bags?}                 23
# Google Merchandise                                 22
# Display Ad created 3/11/15                         22
# Swag with Google Logos                             20
# Ad from 11/3/16                                    18
# 20% discount                                       16
# Display Ad created 11/17/14                        12
# {KeyWord:Google Drinkware}                         11
# {KeyWord:Google Branded Gear}                      10
# Ad from 11/7/16                                     8
# Full auto ad TEXT ONLY                              8
# {KeyWord:Want Google Stickers?}                     7
# {KeyWord:Google Men's T-Shirts}                     7
# JD_5a_v1                                            4
# {KeyWord:Google Branded Kit}                        3
# Official Google Merchandise - Fast Shipping         3
# {KeyWord:Want Google Pet Toys?}                     2
# free shipping                                       2
# Google Paraphernalia                                1
# Full auto ad NATIVE ONLY                            1
# {KeyWord:Google Branded Apparel}                    1
# LeEco_1a                                            1
# Google Store                                        1
# Swag w/ Google Logos                                1
# Free Shipping!                                      1
# Name: adContent, dtype: int64
#
#
# Value counts for campaignCode:
# NaN    193617
# Name: campaignCode, dtype: int64

# %% [markdown]
# ### Rationale for Data Cleaning Actions
# Rows to Drop
# * adwordsClickInfo.criteriaParameters and campaignCode: These columns are identified for removal based on their lack of variability and informational content. Specifically: adwordsClickInfo.criteriaParameters: Every entry in this column is "not available in demo dataset." This uniformity indicates that the column does not provide any unique or actionable information for analysis or modeling purposes. Keeping this column would only consume resources without contributing to insights or predictive power.
#
# * campaignCode: This column contains only NaN values, except for a potential single unique entry which might not be significant for the dataset. A column filled predominantly with missing values, especially in a large dataset, is unlikely to be useful for analysis. It does not contribute to understanding patterns or behaviors within the data, making it a candidate for removal to streamline the dataset and focus on more informative features.

# %%
# Drop specified columns with uniform or missing values
columns_to_drop = ['adwordsClickInfo.criteriaParameters', 'campaignCode']
df.drop(columns=columns_to_drop, inplace=True)

# Display the DataFrame's remaining columns to confirm the changes
print(df.columns)
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'continent', 'subContinent', 'country', 'region', 'metro', 'city',
#        'cityId', 'networkDomain', 'browser', 'operatingSystem', 'isMobile',
#        'deviceCategory', 'hits', 'pageviews', 'bounces', 'newVisits',
#        'transactionRevenue', 'campaign', 'source', 'medium', 'keyword',
#        'isTrueDirect', 'referralPath', 'adwordsClickInfo.page',
#        'adwordsClickInfo.slot', 'adwordsClickInfo.gclId',
#        'adwordsClickInfo.adNetworkType', 'adwordsClickInfo.isVideoAd',
#        'adContent'],
#       dtype='object')

# %%
print('The dimensions of the training dataset are:', df.shape)
# Out:
# The dimensions of the training dataset are: (193617, 37)

# %% [markdown]
# ### Review Strategy for Selected Columns
# Objective
#
# The aim is to conduct a thorough analysis of specific columns within our dataset. This step is critical to ascertain their relevance and utility for our predictive model. Ensuring that each column's data contributes meaningfully to the model's accuracy and insights is paramount. The columns listed below have been flagged for further review based on preliminary observations. The primary concern is the significant presence of missing or NaN values, which could potentially skew the model's performance or lead to inaccurate predictions.
#
# Columns Under Scrutiny
# * Bounces: This column indicates single-page sessions. Its presence or absence could significantly influence user engagement metrics.
# * NewVisits: Represents the number of first-time visits. Critical for understanding new user acquisition.
# * TransactionRevenue: Financial figures are essential for any revenue prediction model or ROI analysis.
# * Campaign: Marketing campaign data can reveal the effectiveness of different marketing strategies.
# * Source: Identifies the origin of web traffic, essential for traffic source analysis.
# * Medium: The medium through which the traffic originated, like organic search, referral, etc.
# * Keyword: Search keywords can offer insights into user intent and content relevance.
# * IsTrueDirect: Indicates whether a session was a direct visit. It's vital for understanding direct traffic's impact.
# * ReferralPath: The path users took to arrive at the site, important for referral traffic analysis.
# * AdwordsClickInfo.page, AdwordsClickInfo.slot, AdwordsClickInfo.gclId, AdwordsClickInfo.adNetworkType, AdwordsClickInfo.isVideoAd: These AdWords-related columns provide granular details about paid search performance.
# * AdContent: Details about the advertisement content, crucial for analyzing the effectiveness of different ad creatives.
#
# Analysis Plan
#
# The review will focus on quantifying the extent of missing data in these columns and determining the impact of these missing values on the dataset's overall integrity and usefulness for modeling. Specifically, we will:
#
# * Calculate the percentage of missing or NaN values for each column.
# * Identify columns where missing data exceeds 50% of the total entries, as these may require special attention, such as imputation, exclusion, or further investigation to understand the nature of their incompleteness.
#
# Goal
#
# * The goal is to optimize our dataset for the predictive modeling process, ensuring that each included feature enhances the model's predictive power and accuracy. The outcome of this review will guide our data preprocessing steps, such as feature selection, imputation strategies, or potential exclusion of features that do not meet our criteria for usefulness and reliability.

# %% [markdown]
# ad* columns have >95% columns missing or NaN so these columns will be dropped

# %%
columns_to_review = [
    'bounces', 'newVisits', 'transactionRevenue', 'campaign', 'source', 
    'medium', 'keyword', 'isTrueDirect', 'referralPath', 'adwordsClickInfo.page',
    'adwordsClickInfo.slot', 'adwordsClickInfo.gclId', 'adwordsClickInfo.adNetworkType',
    'adwordsClickInfo.isVideoAd', 'adContent'
]

for column in columns_to_review:
    # Calculate the percentage of missing values
    missing_percentage = df[column].isna().mean() * 100
    # Check if missing values are greater than 50%
    if missing_percentage > 50:
        print(f"{column}: {missing_percentage:.2f}% of the rows are missing or NaN.")
# Out:
# bounces: 67.46% of the rows are missing or NaN.
# transactionRevenue: 96.56% of the rows are missing or NaN.
# keyword: 61.76% of the rows are missing or NaN.
# isTrueDirect: 53.07% of the rows are missing or NaN.
# referralPath: 63.81% of the rows are missing or NaN.
# adwordsClickInfo.page: 96.14% of the rows are missing or NaN.
# adwordsClickInfo.slot: 96.14% of the rows are missing or NaN.
# adwordsClickInfo.gclId: 96.13% of the rows are missing or NaN.
# adwordsClickInfo.adNetworkType: 96.14% of the rows are missing or NaN.
# adwordsClickInfo.isVideoAd: 96.14% of the rows are missing or NaN.
# adContent: 98.49% of the rows are missing or NaN.

# %%
# List of columns to drop based on the criteria (>80% NaN values)
columns_to_drop = [
    'adwordsClickInfo.page',
    'adwordsClickInfo.slot',
    'adwordsClickInfo.gclId',
    'adwordsClickInfo.adNetworkType',
    'adwordsClickInfo.isVideoAd',
    'adContent'
]

# Drop these columns from the DataFrame
df.drop(columns=columns_to_drop, inplace=True)

# Display the remaining columns to confirm the changes
print("Remaining columns after dropping specified columns with >80% NaN values:")
print(df.columns)
# Out:
# Remaining columns after dropping specified columns with >80% NaN values:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'continent', 'subContinent', 'country', 'region', 'metro', 'city',
#        'cityId', 'networkDomain', 'browser', 'operatingSystem', 'isMobile',
#        'deviceCategory', 'hits', 'pageviews', 'bounces', 'newVisits',
#        'transactionRevenue', 'campaign', 'source', 'medium', 'keyword',
#        'isTrueDirect', 'referralPath'],
#       dtype='object')

# %%
print('The dimensions of the training dataset are:', df.shape)
# Out:
# The dimensions of the training dataset are: (193617, 31)

# %%
# Iterate over all column names in the DataFrame
for column in df.columns:
    print(f"Value counts for {column}:")
    print(df[column].value_counts(dropna=False))  # Include NaN counts
    print("\n")  # Adds a newline for better readability between columns
# Out:
# Value counts for channelGrouping:
# Organic Search    68237
# Referral          61065
# Direct            41727
# Social             8996
# Paid Search        8021
# Display            3850
# Affiliates         1660
# (Other)              61
# Name: channelGrouping, dtype: int64
#
#
# Value counts for date:
# 2017-05-16    1396
# 2016-12-19    1349
# 2016-10-04    1175
# 2016-12-12    1170
# 2017-04-26    1164
#               ...
# 2017-05-06     170
# 2017-02-12     170
# 2017-01-14     169
# 2016-08-13     167
# 2016-10-01     146
# Name: date, Length: 366, dtype: int64
#
#
# Value counts for fullVisitorId:
# 824839726118485274     230
# 7634897085866546110    126
# 949718915643445721     107
# 6254908847172458133    101
# 9609104828919391966     98
#                       ...
# 2514418634771358752      1
# 560016838311060230       1
# 6254351152298198797      1
# 7272597777661582423      1
# 2035095632074835075      1
# Name: fullVisitorId, Length: 128937, dtype: int64
#
#
# Value counts for sessionId:
# 7088163533987137698_1488441216    2
# 5643319853745503187_1481874929    2
# 6667424077677299781_1498631774    2
# 9248188248183652052_1472453841    2
# 7483600664917507409_1476512865    2
#                                  ..
# 4578640586284138624_1473793915    1
# 8881859026571518968_1473811154    1
# 1616635312025969512_1473806638    1
# 5745691898696443704_1473787896    1
# 2035095632074835075_1483570454    1
# Name: sessionId, Length: 193437, dtype: int64
#
#
# Value counts for socialEngagementType:
# Not Socially Engaged    193617
# Name: socialEngagementType, dtype: int64
#
#
# Value counts for visitId:
# 1484649802    6
# 1479668456    4
# 1475719086    4
# 1488904421    4
# 1484649800    4
#              ..
# 1473809384    1
# 1473785522    1
# 1473774965    1
# 1473774937    1
# 1483570454    1
# Name: visitId, Length: 192129, dtype: int64
#
#
# Value counts for visitNumber:
# 1      117642
# 2       30415
# 3       13912
# 4        8158
# 5        5186
#         ...
# 303         1
# 302         1
# 266         1
# 265         1
# 377         1
# Name: visitNumber, Length: 355, dtype: int64
#
#
# Value counts for visitStartTime:
# 1484649802    6
# 1479668456    4
# 1488904421    4
# 1475719086    4
# 1484649800    4
#              ..
# 1473771208    1
# 1473816989    1
# 1473798894    1
# 1473799304    1
# 1483570454    1
# Name: visitStartTime, Length: 192307, dtype: int64
#
#
# Value counts for continent:
# Americas    179537
# Europe       13418
# Asia           624
# Oceania         31
# Africa           7
# Name: continent, dtype: int64
#
#
# Value counts for subContinent:
# Northern America      179463
# Northern Europe        13223
# Eastern Asia             466
# Western Europe           132
# Southern Asia             77
# Southeast Asia            46
# Southern Europe           44
# Central America           41
# Western Asia              35
# Australasia               30
# South America             28
# Eastern Europe            19
# Caribbean                  5
# Southern Africa            4
# Western Africa             2
# Eastern Africa             1
# Micronesian Region         1
# Name: subContinent, dtype: int64
#
#
# Value counts for country:
# United States         179305
# United Kingdom         13156
# Japan                    352
# Canada                   158
# India                     75
#                        ...
# Dominican Republic         1
# Guam                       1
# Kenya                      1
# Austria                    1
# Lebanon                    1
# Name: country, Length: 64, dtype: int64
#
#
# Value counts for region:
# California              107492
# New York                 26427
# England                  13162
# Texas                     8739
# Washington                7642
# Illinois                  7579
# Virginia                  3094
# Massachusetts             2640
# Michigan                  2578
# District of Columbia      2532
# Georgia                   2475
# Pennsylvania              1846
# Oregon                    1319
# Colorado                   893
# Ohio                       654
# Florida                    596
# North Carolina             580
# New Jersey                 563
# Arizona                    544
# Wisconsin                  543
# Tokyo                      257
# Minnesota                  211
# Tennessee                  209
# Missouri                   129
# Iowa                        95
# Scotland                    86
# Nevada                      76
# Kentucky                    70
# Kansas                      68
# South Carolina              68
# Idaho                       62
# Utah                        62
# Connecticut                 61
# Indiana                     55
# Maryland                    45
# Nebraska                    34
# Osaka Prefecture            26
# Kanagawa Prefecture         22
# Hawaii                      21
# Wales                       20
# West Virginia               14
# Fukui Prefecture            12
# Louisiana                    7
# Oklahoma                     6
# Montana                      3
# Name: region, dtype: int64
#
#
# Value counts for metro:
# San Francisco-Oakland-San Jose CA    95910
# New York NY                          26911
# London                               12564
# Los Angeles CA                        9995
# Seattle-Tacoma WA                     7642
#                                      ...
# Rochester-Mason City-Austin,IA           6
# Springfield-Holyoke MA                   6
# Chattanooga TN                           6
# Boise ID                                 3
# Butte-Bozeman MT                         3
# Name: metro, Length: 92, dtype: int64
#
#
# Value counts for city:
# Mountain View    40884
# New York         26365
# San Francisco    20326
# Sunnyvale        13086
# London           12436
#                  ...
# Campbell             5
# Douglasville         5
# Daly City            4
# Boise                3
# Bozeman              3
# Name: city, Length: 225, dtype: int64
#
#
# Value counts for cityId:
# not available in demo dataset    193617
# Name: cityId, dtype: int64
#
#
# Value counts for networkDomain:
# (not set)                 115800
# comcast.net                12968
# unknown.unknown             9146
# comcastbusiness.net         4718
# rr.com                      4531
#                            ...
# twowincolimited-hk.com         1
# doc.gov                        1
# aaminc.com                     1
# versaceus.com                  1
# northshore.org                 1
# Name: networkDomain, Length: 3048, dtype: int64
#
#
# Value counts for browser:
# Chrome                      157763
# Safari                       25946
# Firefox                       2924
# Internet Explorer             2294
# Safari (in-app)               1381
# Opera                         1212
# Edge                          1208
# Android Webview                560
# YaBrowser                      122
# Amazon Silk                     59
# UC Browser                      27
# Android Browser                 23
# Coc Coc                         22
# Iron                            18
# Opera Mini                      14
# BlackBerry                      13
# Maxthon                         10
# MRCHROME                         7
# Nichrome                         4
# Nintendo Browser                 3
# Mozilla Compatible Agent         3
# Mozilla                          2
# YE                               1
# Puffin                           1
# Name: browser, dtype: int64
#
#
# Value counts for operatingSystem:
# Macintosh        84006
# Windows          33485
# iOS              26168
# Linux            19889
# Android          19824
# Chrome OS        10161
# Windows Phone       62
# BlackBerry          14
# Xbox                 3
# Nintendo WiiU        2
# Nintendo Wii         1
# FreeBSD              1
# Samsung              1
# Name: operatingSystem, dtype: int64
#
#
# Value counts for isMobile:
# False    147399
# True      46218
# Name: isMobile, dtype: int64
#
#
# Value counts for deviceCategory:
# desktop    147404
# mobile      42760
# tablet       3453
# Name: deviceCategory, dtype: int64
#
#
# Value counts for hits:
# 1      62476
# 2      25285
# 3      19153
# 4      13577
# 5      10225
#        ...
# 301        1
# 192        1
# 259        1
# 286        1
# 308        1
# Name: hits, Length: 210, dtype: int64
#
#
# Value counts for pageviews:
# 1.0      63614
# 2.0      26841
# 3.0      20620
# 4.0      14771
# 5.0      11312
#          ...
# 270.0        1
# 193.0        1
# 162.0        1
# 137.0        1
# 98.0         1
# Name: pageviews, Length: 156, dtype: int64
#
#
# Value counts for bounces:
# NaN    130611
# 1.0     63006
# Name: bounces, dtype: int64
#
#
# Value counts for newVisits:
# 1.0    117642
# NaN     75975
# Name: newVisits, dtype: int64
#
#
# Value counts for transactionRevenue:
# NaN            186951
# 33590000.0        160
# 44790000.0        132
# 13590000.0        104
# 16990000.0         76
#                 ...
# 491400000.0         1
# 104340000.0         1
# 410980000.0         1
# 339660000.0         1
# 69390000.0          1
# Name: transactionRevenue, Length: 3494, dtype: int64
#
#
# Value counts for campaign:
# (not set)                                          184451
# AW - Dynamic Search Ads Whole Site                   5080
# AW - Accessories                                     2362
# Data Share Promo                                     1660
# test-liyuhz                                            22
# AW - Electronics                                       18
# Retail (DO NOT EDIT owners nophakun and tianyu)        12
# AW - Apparel                                            8
# All Products                                            3
# Data Share                                              1
# Name: campaign, dtype: int64
#
#
# Value counts for source:
# google                                               76188
# mall.googleplex.com                                  52205
# (direct)                                             41728
# youtube.com                                           6119
# dfa                                                   3315
#                                                      ...
# login.corp.google.com                                    1
# plusapp-autopush.corp.google.com                         1
# 0.shared.bow.cat2.ads-bow.qk.borg.google.com:9819        1
# vk.com                                                   1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898        1
# Name: source, Length: 211, dtype: int64
#
#
# Value counts for medium:
# referral     70061
# organic      68237
# (none)       41727
# cpc           8021
# cpm           3850
# affiliate     1660
# (not set)       61
# Name: medium, dtype: int64
#
#
# Value counts for keyword:
# NaN                           119580
# (not provided)                 65569
# 6qEhsCssdK0z36ri                4241
# google merchandise store        1096
# 1hZbAqLCbjwfgOH7                 707
#                                ...
# google notebooks                   1
# lava floor lamp                    1
# Youtube water bottle merch         1
# google store sell t shirt          1
# google backback                    1
# Name: keyword, Length: 257, dtype: int64
#
#
# Value counts for isTrueDirect:
# NaN     102760
# True     90857
# Name: isTrueDirect, dtype: int64
#
#
# Value counts for referralPath:
# NaN                                                                                                                                                               123556
# /                                                                                                                                                                  54081
# /yt/about/                                                                                                                                                          4583
# /analytics/web/                                                                                                                                                     1540
# /a/google.com/googletopia/discounts-deals-and-free-stuff/alphabet-google-discounts                                                                                   814
#                                                                                                                                                                    ...
# /FG0oftTBYt                                                                                                                                                            1
# /ads/richmedia/studio/pv2/45678657/dirty/index.html                                                                                                                    1
# /a/google.com/nestlabs/the-nest-pulse                                                                                                                                  1
# /from=2001a/bd_page_type=1/ssid=0/uid=0/pu=usm%402%2Csz%401320_1001%2Cta%40iphone_2_6.0_3_537/baiduid=494FFE6533C49BB85AC76FCE5488FE5B/w=0_10_/t=iphone/l=3/tc         1
# /mail/mu/mp/509/                                                                                                                                                       1
# Name: referralPath, Length: 717, dtype: int64

# %%
columns_to_review = [
    'bounces', 'newVisits', 'transactionRevenue', 'campaign', 'source', 
    'medium', 'keyword', 'isTrueDirect', 'referralPath'
]

for column in columns_to_review:
    # Calculate the percentage of missing values
    missing_percentage = df[column].isna().mean() * 100
    # Check if missing values are greater than 50%
    
    print(f"{column}: {missing_percentage:.2f}% of the rows are missing or NaN.")
# Out:
# bounces: 67.46% of the rows are missing or NaN.
# newVisits: 39.24% of the rows are missing or NaN.
# transactionRevenue: 96.56% of the rows are missing or NaN.
# campaign: 0.00% of the rows are missing or NaN.
# source: 0.00% of the rows are missing or NaN.
# medium: 0.00% of the rows are missing or NaN.
# keyword: 61.76% of the rows are missing or NaN.
# isTrueDirect: 53.07% of the rows are missing or NaN.
# referralPath: 63.81% of the rows are missing or NaN.

# %% [markdown]
# ### Data Cleaning Strategy and Execution Plan
#
# Before making any modifications to our DataFrame (df), let's establish a checkpoint to preserve our current dataset state. This approach allows us to maintain a reference point and potentially revert changes if necessary.

# %%
df_checkpoint2 = df.copy()

# %% [markdown]
# ### Actions to Undertake
# * Bounces
# Action: Convert NaN values to 0. The rationale is that if a session isn't explicitly marked as a bounce (1), it should be considered a non-bounce session (0).
# * Keyword
# Action: Drop the keyword column due to a high volume of NaN values and potentially limited predictive value.
# * IsTrueDirect
# Action: Convert NaN values to False. If a session is not explicitly marked as directly accessed (True), it is assumed not to be a direct access (False).

# %%
df['bounces'].fillna(0, inplace=True)
df.drop(columns=['keyword'], inplace=True)

# %% [markdown]
# IsTrueDirect
# Action: Convert NaN values to False. If a session is not explicitly marked as directly accessed (True), it is assumed not to be a direct access (False).

# %%
df['isTrueDirect'].fillna(False, inplace=True)

# %% [markdown]
# ### More Actions to Undertake
#
# * NewVisits
# Description: Marks a new visit (newVisit = 1). NaN likely signifies returning visits.
# Strategy: Similar to bounces, convert NaN to 0, marking returning visits. This conversion maintains the binary feature's consistency.
#
# * TransactionRevenue
# Description: Financial figures, with NaN indicating no revenue from the transaction.
# Strategy: Replace NaN with 0 to represent sessions without revenue, which is common in datasets where transactions are sparse.
#
# * Refferal Path
# Column contain >50% missing values and is complex to handel so we will drop.

# %%
# Convert NaN to 0 for 'NewVisits' to indicate returning visits
df['newVisits'].fillna(0, inplace=True)

# Replace NaN with 0 in 'TransactionRevenue' to represent sessions without revenue
df['transactionRevenue'].fillna(0, inplace=True)

# Drop the 'ReferralPath' column due to its complexity and high percentage of missing values
df.drop(columns=['referralPath'], inplace=True)

# Confirming the execution of specified data cleaning actions
print("Specified data cleaning actions have been executed.")
print("Remaining columns:", df.columns)
# Out:
# Specified data cleaning actions have been executed.
# Remaining columns: Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'continent', 'subContinent', 'country', 'region', 'metro', 'city',
#        'cityId', 'networkDomain', 'browser', 'operatingSystem', 'isMobile',
#        'deviceCategory', 'hits', 'pageviews', 'bounces', 'newVisits',
#        'transactionRevenue', 'campaign', 'source', 'medium', 'isTrueDirect'],
#       dtype='object')

# %%
columns_to_review = [
    'campaign', 'medium'
]

for column in columns_to_review:
    # Calculate the percentage of missing values
    missing_percentage = df[column].isna().mean() * 100
    # Check if missing values are greater than 50%
    
    print(f"{column}: {missing_percentage:.2f}% of the rows are missing or NaN.")
# Out:
# campaign: 0.00% of the rows are missing or NaN.
# medium: 0.00% of the rows are missing or NaN.

# %%
# Iterate over all column names in the DataFrame
for column in df.columns:
    print(f"Value counts for {column}:")
    print(df[column].value_counts(dropna=False))  # Include NaN counts
    print("\n")  # Adds a newline for better readability between columns
# Out:
# Value counts for channelGrouping:
# Organic Search    68237
# Referral          61065
# Direct            41727
# Social             8996
# Paid Search        8021
# Display            3850
# Affiliates         1660
# (Other)              61
# Name: channelGrouping, dtype: int64
#
#
# Value counts for date:
# 2017-05-16    1396
# 2016-12-19    1349
# 2016-10-04    1175
# 2016-12-12    1170
# 2017-04-26    1164
#               ...
# 2017-05-06     170
# 2017-02-12     170
# 2017-01-14     169
# 2016-08-13     167
# 2016-10-01     146
# Name: date, Length: 366, dtype: int64
#
#
# Value counts for fullVisitorId:
# 824839726118485274     230
# 7634897085866546110    126
# 949718915643445721     107
# 6254908847172458133    101
# 9609104828919391966     98
#                       ...
# 2514418634771358752      1
# 560016838311060230       1
# 6254351152298198797      1
# 7272597777661582423      1
# 2035095632074835075      1
# Name: fullVisitorId, Length: 128937, dtype: int64
#
#
# Value counts for sessionId:
# 7088163533987137698_1488441216    2
# 5643319853745503187_1481874929    2
# 6667424077677299781_1498631774    2
# 9248188248183652052_1472453841    2
# 7483600664917507409_1476512865    2
#                                  ..
# 4578640586284138624_1473793915    1
# 8881859026571518968_1473811154    1
# 1616635312025969512_1473806638    1
# 5745691898696443704_1473787896    1
# 2035095632074835075_1483570454    1
# Name: sessionId, Length: 193437, dtype: int64
#
#
# Value counts for socialEngagementType:
# Not Socially Engaged    193617
# Name: socialEngagementType, dtype: int64
#
#
# Value counts for visitId:
# 1484649802    6
# 1479668456    4
# 1475719086    4
# 1488904421    4
# 1484649800    4
#              ..
# 1473809384    1
# 1473785522    1
# 1473774965    1
# 1473774937    1
# 1483570454    1
# Name: visitId, Length: 192129, dtype: int64
#
#
# Value counts for visitNumber:
# 1      117642
# 2       30415
# 3       13912
# 4        8158
# 5        5186
#         ...
# 303         1
# 302         1
# 266         1
# 265         1
# 377         1
# Name: visitNumber, Length: 355, dtype: int64
#
#
# Value counts for visitStartTime:
# 1484649802    6
# 1479668456    4
# 1488904421    4
# 1475719086    4
# 1484649800    4
#              ..
# 1473771208    1
# 1473816989    1
# 1473798894    1
# 1473799304    1
# 1483570454    1
# Name: visitStartTime, Length: 192307, dtype: int64
#
#
# Value counts for continent:
# Americas    179537
# Europe       13418
# Asia           624
# Oceania         31
# Africa           7
# Name: continent, dtype: int64
#
#
# Value counts for subContinent:
# Northern America      179463
# Northern Europe        13223
# Eastern Asia             466
# Western Europe           132
# Southern Asia             77
# Southeast Asia            46
# Southern Europe           44
# Central America           41
# Western Asia              35
# Australasia               30
# South America             28
# Eastern Europe            19
# Caribbean                  5
# Southern Africa            4
# Western Africa             2
# Eastern Africa             1
# Micronesian Region         1
# Name: subContinent, dtype: int64
#
#
# Value counts for country:
# United States         179305
# United Kingdom         13156
# Japan                    352
# Canada                   158
# India                     75
#                        ...
# Dominican Republic         1
# Guam                       1
# Kenya                      1
# Austria                    1
# Lebanon                    1
# Name: country, Length: 64, dtype: int64
#
#
# Value counts for region:
# California              107492
# New York                 26427
# England                  13162
# Texas                     8739
# Washington                7642
# Illinois                  7579
# Virginia                  3094
# Massachusetts             2640
# Michigan                  2578
# District of Columbia      2532
# Georgia                   2475
# Pennsylvania              1846
# Oregon                    1319
# Colorado                   893
# Ohio                       654
# Florida                    596
# North Carolina             580
# New Jersey                 563
# Arizona                    544
# Wisconsin                  543
# Tokyo                      257
# Minnesota                  211
# Tennessee                  209
# Missouri                   129
# Iowa                        95
# Scotland                    86
# Nevada                      76
# Kentucky                    70
# Kansas                      68
# South Carolina              68
# Idaho                       62
# Utah                        62
# Connecticut                 61
# Indiana                     55
# Maryland                    45
# Nebraska                    34
# Osaka Prefecture            26
# Kanagawa Prefecture         22
# Hawaii                      21
# Wales                       20
# West Virginia               14
# Fukui Prefecture            12
# Louisiana                    7
# Oklahoma                     6
# Montana                      3
# Name: region, dtype: int64
#
#
# Value counts for metro:
# San Francisco-Oakland-San Jose CA    95910
# New York NY                          26911
# London                               12564
# Los Angeles CA                        9995
# Seattle-Tacoma WA                     7642
#                                      ...
# Rochester-Mason City-Austin,IA           6
# Springfield-Holyoke MA                   6
# Chattanooga TN                           6
# Boise ID                                 3
# Butte-Bozeman MT                         3
# Name: metro, Length: 92, dtype: int64
#
#
# Value counts for city:
# Mountain View    40884
# New York         26365
# San Francisco    20326
# Sunnyvale        13086
# London           12436
#                  ...
# Campbell             5
# Douglasville         5
# Daly City            4
# Boise                3
# Bozeman              3
# Name: city, Length: 225, dtype: int64
#
#
# Value counts for cityId:
# not available in demo dataset    193617
# Name: cityId, dtype: int64
#
#
# Value counts for networkDomain:
# (not set)                 115800
# comcast.net                12968
# unknown.unknown             9146
# comcastbusiness.net         4718
# rr.com                      4531
#                            ...
# twowincolimited-hk.com         1
# doc.gov                        1
# aaminc.com                     1
# versaceus.com                  1
# northshore.org                 1
# Name: networkDomain, Length: 3048, dtype: int64
#
#
# Value counts for browser:
# Chrome                      157763
# Safari                       25946
# Firefox                       2924
# Internet Explorer             2294
# Safari (in-app)               1381
# Opera                         1212
# Edge                          1208
# Android Webview                560
# YaBrowser                      122
# Amazon Silk                     59
# UC Browser                      27
# Android Browser                 23
# Coc Coc                         22
# Iron                            18
# Opera Mini                      14
# BlackBerry                      13
# Maxthon                         10
# MRCHROME                         7
# Nichrome                         4
# Nintendo Browser                 3
# Mozilla Compatible Agent         3
# Mozilla                          2
# YE                               1
# Puffin                           1
# Name: browser, dtype: int64
#
#
# Value counts for operatingSystem:
# Macintosh        84006
# Windows          33485
# iOS              26168
# Linux            19889
# Android          19824
# Chrome OS        10161
# Windows Phone       62
# BlackBerry          14
# Xbox                 3
# Nintendo WiiU        2
# Nintendo Wii         1
# FreeBSD              1
# Samsung              1
# Name: operatingSystem, dtype: int64
#
#
# Value counts for isMobile:
# False    147399
# True      46218
# Name: isMobile, dtype: int64
#
#
# Value counts for deviceCategory:
# desktop    147404
# mobile      42760
# tablet       3453
# Name: deviceCategory, dtype: int64
#
#
# Value counts for hits:
# 1      62476
# 2      25285
# 3      19153
# 4      13577
# 5      10225
#        ...
# 301        1
# 192        1
# 259        1
# 286        1
# 308        1
# Name: hits, Length: 210, dtype: int64
#
#
# Value counts for pageviews:
# 1.0      63614
# 2.0      26841
# 3.0      20620
# 4.0      14771
# 5.0      11312
#          ...
# 270.0        1
# 193.0        1
# 162.0        1
# 137.0        1
# 98.0         1
# Name: pageviews, Length: 156, dtype: int64
#
#
# Value counts for bounces:
# 0.0    130611
# 1.0     63006
# Name: bounces, dtype: int64
#
#
# Value counts for newVisits:
# 1.0    117642
# 0.0     75975
# Name: newVisits, dtype: int64
#
#
# Value counts for transactionRevenue:
# 0.0            186951
# 33590000.0        160
# 44790000.0        132
# 13590000.0        104
# 16990000.0         76
#                 ...
# 491400000.0         1
# 104340000.0         1
# 410980000.0         1
# 339660000.0         1
# 69390000.0          1
# Name: transactionRevenue, Length: 3494, dtype: int64
#
#
# Value counts for campaign:
# (not set)                                          184451
# AW - Dynamic Search Ads Whole Site                   5080
# AW - Accessories                                     2362
# Data Share Promo                                     1660
# test-liyuhz                                            22
# AW - Electronics                                       18
# Retail (DO NOT EDIT owners nophakun and tianyu)        12
# AW - Apparel                                            8
# All Products                                            3
# Data Share                                              1
# Name: campaign, dtype: int64
#
#
# Value counts for source:
# google                                               76188
# mall.googleplex.com                                  52205
# (direct)                                             41728
# youtube.com                                           6119
# dfa                                                   3315
#                                                      ...
# login.corp.google.com                                    1
# plusapp-autopush.corp.google.com                         1
# 0.shared.bow.cat2.ads-bow.qk.borg.google.com:9819        1
# vk.com                                                   1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898        1
# Name: source, Length: 211, dtype: int64
#
#
# Value counts for medium:
# referral     70061
# organic      68237
# (none)       41727
# cpc           8021
# cpm           3850
# affiliate     1660
# (not set)       61
# Name: medium, dtype: int64
#
#
# Value counts for isTrueDirect:
# False    102760
# True      90857
# Name: isTrueDirect, dtype: int64

# %% [markdown]
# * Campaign
# Description: Marketing campaign information, with "(not set)" indicating sessions not attributed to any campaign.
# Strategy: If "(not set)" represents a significant portion of the data, consider it as a separate category or replace it with a more descriptive term like "No Campaign." Evaluate the impact of this feature on your model before deciding.
# * Medium
# Description: The medium through which the traffic arrived.
# Strategy: This column is valuable for analysis. Consider grouping less common mediums into an "other" category to simplify the model's input space. And Remove the row were medium == "(not set)"

# %%
# Handling 'Campaign'
df['campaign'] = df['campaign'].replace("(not set)", "No Campaign")

# Handling 'Medium'
# Placeholder for the specific mediums to keep
medium_list = ['referral', 'organic', 'cpc', 'cpm', 'affiliate']  # Adjust based on your analysis
df['medium'] = df['medium'].apply(lambda x: x if x in medium_list else 'other')
df = df[df['medium'] != "(not set)"]

# %%
# Iterate over all column names in the DataFrame
for column in df.columns:
    print(f"Value counts for {column}:")
    print(df[column].value_counts(dropna=False))  # Include NaN counts
    print("\n")  # Adds a newline for better readability between columns
# Out:
# Value counts for channelGrouping:
# Organic Search    68237
# Referral          61065
# Direct            41727
# Social             8996
# Paid Search        8021
# Display            3850
# Affiliates         1660
# (Other)              61
# Name: channelGrouping, dtype: int64
#
#
# Value counts for date:
# 2017-05-16    1396
# 2016-12-19    1349
# 2016-10-04    1175
# 2016-12-12    1170
# 2017-04-26    1164
#               ...
# 2017-05-06     170
# 2017-02-12     170
# 2017-01-14     169
# 2016-08-13     167
# 2016-10-01     146
# Name: date, Length: 366, dtype: int64
#
#
# Value counts for fullVisitorId:
# 824839726118485274     230
# 7634897085866546110    126
# 949718915643445721     107
# 6254908847172458133    101
# 9609104828919391966     98
#                       ...
# 2514418634771358752      1
# 560016838311060230       1
# 6254351152298198797      1
# 7272597777661582423      1
# 2035095632074835075      1
# Name: fullVisitorId, Length: 128937, dtype: int64
#
#
# Value counts for sessionId:
# 7088163533987137698_1488441216    2
# 5643319853745503187_1481874929    2
# 6667424077677299781_1498631774    2
# 9248188248183652052_1472453841    2
# 7483600664917507409_1476512865    2
#                                  ..
# 4578640586284138624_1473793915    1
# 8881859026571518968_1473811154    1
# 1616635312025969512_1473806638    1
# 5745691898696443704_1473787896    1
# 2035095632074835075_1483570454    1
# Name: sessionId, Length: 193437, dtype: int64
#
#
# Value counts for socialEngagementType:
# Not Socially Engaged    193617
# Name: socialEngagementType, dtype: int64
#
#
# Value counts for visitId:
# 1484649802    6
# 1479668456    4
# 1475719086    4
# 1488904421    4
# 1484649800    4
#              ..
# 1473809384    1
# 1473785522    1
# 1473774965    1
# 1473774937    1
# 1483570454    1
# Name: visitId, Length: 192129, dtype: int64
#
#
# Value counts for visitNumber:
# 1      117642
# 2       30415
# 3       13912
# 4        8158
# 5        5186
#         ...
# 303         1
# 302         1
# 266         1
# 265         1
# 377         1
# Name: visitNumber, Length: 355, dtype: int64
#
#
# Value counts for visitStartTime:
# 1484649802    6
# 1479668456    4
# 1488904421    4
# 1475719086    4
# 1484649800    4
#              ..
# 1473771208    1
# 1473816989    1
# 1473798894    1
# 1473799304    1
# 1483570454    1
# Name: visitStartTime, Length: 192307, dtype: int64
#
#
# Value counts for continent:
# Americas    179537
# Europe       13418
# Asia           624
# Oceania         31
# Africa           7
# Name: continent, dtype: int64
#
#
# Value counts for subContinent:
# Northern America      179463
# Northern Europe        13223
# Eastern Asia             466
# Western Europe           132
# Southern Asia             77
# Southeast Asia            46
# Southern Europe           44
# Central America           41
# Western Asia              35
# Australasia               30
# South America             28
# Eastern Europe            19
# Caribbean                  5
# Southern Africa            4
# Western Africa             2
# Eastern Africa             1
# Micronesian Region         1
# Name: subContinent, dtype: int64
#
#
# Value counts for country:
# United States         179305
# United Kingdom         13156
# Japan                    352
# Canada                   158
# India                     75
#                        ...
# Dominican Republic         1
# Guam                       1
# Kenya                      1
# Austria                    1
# Lebanon                    1
# Name: country, Length: 64, dtype: int64
#
#
# Value counts for region:
# California              107492
# New York                 26427
# England                  13162
# Texas                     8739
# Washington                7642
# Illinois                  7579
# Virginia                  3094
# Massachusetts             2640
# Michigan                  2578
# District of Columbia      2532
# Georgia                   2475
# Pennsylvania              1846
# Oregon                    1319
# Colorado                   893
# Ohio                       654
# Florida                    596
# North Carolina             580
# New Jersey                 563
# Arizona                    544
# Wisconsin                  543
# Tokyo                      257
# Minnesota                  211
# Tennessee                  209
# Missouri                   129
# Iowa                        95
# Scotland                    86
# Nevada                      76
# Kentucky                    70
# Kansas                      68
# South Carolina              68
# Idaho                       62
# Utah                        62
# Connecticut                 61
# Indiana                     55
# Maryland                    45
# Nebraska                    34
# Osaka Prefecture            26
# Kanagawa Prefecture         22
# Hawaii                      21
# Wales                       20
# West Virginia               14
# Fukui Prefecture            12
# Louisiana                    7
# Oklahoma                     6
# Montana                      3
# Name: region, dtype: int64
#
#
# Value counts for metro:
# San Francisco-Oakland-San Jose CA    95910
# New York NY                          26911
# London                               12564
# Los Angeles CA                        9995
# Seattle-Tacoma WA                     7642
#                                      ...
# Rochester-Mason City-Austin,IA           6
# Springfield-Holyoke MA                   6
# Chattanooga TN                           6
# Boise ID                                 3
# Butte-Bozeman MT                         3
# Name: metro, Length: 92, dtype: int64
#
#
# Value counts for city:
# Mountain View    40884
# New York         26365
# San Francisco    20326
# Sunnyvale        13086
# London           12436
#                  ...
# Campbell             5
# Douglasville         5
# Daly City            4
# Boise                3
# Bozeman              3
# Name: city, Length: 225, dtype: int64
#
#
# Value counts for cityId:
# not available in demo dataset    193617
# Name: cityId, dtype: int64
#
#
# Value counts for networkDomain:
# (not set)                 115800
# comcast.net                12968
# unknown.unknown             9146
# comcastbusiness.net         4718
# rr.com                      4531
#                            ...
# twowincolimited-hk.com         1
# doc.gov                        1
# aaminc.com                     1
# versaceus.com                  1
# northshore.org                 1
# Name: networkDomain, Length: 3048, dtype: int64
#
#
# Value counts for browser:
# Chrome                      157763
# Safari                       25946
# Firefox                       2924
# Internet Explorer             2294
# Safari (in-app)               1381
# Opera                         1212
# Edge                          1208
# Android Webview                560
# YaBrowser                      122
# Amazon Silk                     59
# UC Browser                      27
# Android Browser                 23
# Coc Coc                         22
# Iron                            18
# Opera Mini                      14
# BlackBerry                      13
# Maxthon                         10
# MRCHROME                         7
# Nichrome                         4
# Nintendo Browser                 3
# Mozilla Compatible Agent         3
# Mozilla                          2
# YE                               1
# Puffin                           1
# Name: browser, dtype: int64
#
#
# Value counts for operatingSystem:
# Macintosh        84006
# Windows          33485
# iOS              26168
# Linux            19889
# Android          19824
# Chrome OS        10161
# Windows Phone       62
# BlackBerry          14
# Xbox                 3
# Nintendo WiiU        2
# Nintendo Wii         1
# FreeBSD              1
# Samsung              1
# Name: operatingSystem, dtype: int64
#
#
# Value counts for isMobile:
# False    147399
# True      46218
# Name: isMobile, dtype: int64
#
#
# Value counts for deviceCategory:
# desktop    147404
# mobile      42760
# tablet       3453
# Name: deviceCategory, dtype: int64
#
#
# Value counts for hits:
# 1      62476
# 2      25285
# 3      19153
# 4      13577
# 5      10225
#        ...
# 301        1
# 192        1
# 259        1
# 286        1
# 308        1
# Name: hits, Length: 210, dtype: int64
#
#
# Value counts for pageviews:
# 1.0      63614
# 2.0      26841
# 3.0      20620
# 4.0      14771
# 5.0      11312
#          ...
# 270.0        1
# 193.0        1
# 162.0        1
# 137.0        1
# 98.0         1
# Name: pageviews, Length: 156, dtype: int64
#
#
# Value counts for bounces:
# 0.0    130611
# 1.0     63006
# Name: bounces, dtype: int64
#
#
# Value counts for newVisits:
# 1.0    117642
# 0.0     75975
# Name: newVisits, dtype: int64
#
#
# Value counts for transactionRevenue:
# 0.0            186951
# 33590000.0        160
# 44790000.0        132
# 13590000.0        104
# 16990000.0         76
#                 ...
# 491400000.0         1
# 104340000.0         1
# 410980000.0         1
# 339660000.0         1
# 69390000.0          1
# Name: transactionRevenue, Length: 3494, dtype: int64
#
#
# Value counts for campaign:
# No Campaign                                        184451
# AW - Dynamic Search Ads Whole Site                   5080
# AW - Accessories                                     2362
# Data Share Promo                                     1660
# test-liyuhz                                            22
# AW - Electronics                                       18
# Retail (DO NOT EDIT owners nophakun and tianyu)        12
# AW - Apparel                                            8
# All Products                                            3
# Data Share                                              1
# Name: campaign, dtype: int64
#
#
# Value counts for source:
# google                                               76188
# mall.googleplex.com                                  52205
# (direct)                                             41728
# youtube.com                                           6119
# dfa                                                   3315
#                                                      ...
# login.corp.google.com                                    1
# plusapp-autopush.corp.google.com                         1
# 0.shared.bow.cat2.ads-bow.qk.borg.google.com:9819        1
# vk.com                                                   1
# 0.shared.bow.cat2.ads-bow.yw.borg.google.com:9898        1
# Name: source, Length: 211, dtype: int64
#
#
# Value counts for medium:
# referral     70061
# organic      68237
# other        41788
# cpc           8021
# cpm           3850
# affiliate     1660
# Name: medium, dtype: int64
#
#
# Value counts for isTrueDirect:
# False    102760
# True      90857
# Name: isTrueDirect, dtype: int64

# %%
print('The dimensions of the training dataset are:', df.shape)
# Out:
# The dimensions of the training dataset are: (193617, 29)

# %%
# Get the value counts for 'pageviews', including NaN values
pageviews_counts = df['pageviews'].value_counts(dropna=False).sort_index()

# Print each unique value and its count
for pageview, count in pageviews_counts.items():
    print(f"{pageview}: {count}")
# Out:
# 1.0: 63614
# 2.0: 26841
# 3.0: 20620
# 4.0: 14771
# 5.0: 11312
# 6.0: 8656
# 7.0: 6835
# 8.0: 5313
# 9.0: 4441
# 10.0: 3604
# 11.0: 3002
# 12.0: 2551
# 13.0: 2217
# 14.0: 1990
# 15.0: 1757
# 16.0: 1465
# 17.0: 1310
# 18.0: 1206
# 19.0: 987
# 20.0: 964
# 21.0: 875
# 22.0: 738
# 23.0: 683
# 24.0: 629
# 25.0: 527
# 26.0: 557
# 27.0: 460
# 28.0: 415
# 29.0: 354
# 30.0: 338
# 31.0: 354
# 32.0: 305
# 33.0: 278
# 34.0: 220
# 35.0: 218
# 36.0: 204
# 37.0: 184
# 38.0: 186
# 39.0: 161
# 40.0: 150
# 41.0: 148
# 42.0: 136
# 43.0: 112
# 44.0: 105
# 45.0: 125
# 46.0: 93
# 47.0: 107
# 48.0: 105
# 49.0: 82
# 50.0: 63
# 51.0: 76
# 52.0: 75
# 53.0: 56
# 54.0: 43
# 55.0: 61
# 56.0: 44
# 57.0: 47
# 58.0: 41
# 59.0: 41
# 60.0: 39
# 61.0: 39
# 62.0: 30
# 63.0: 33
# 64.0: 37
# 65.0: 35
# 66.0: 28
# 67.0: 27
# 68.0: 24
# 69.0: 21
# 70.0: 22
# 71.0: 17
# 72.0: 12
# 73.0: 13
# 74.0: 15
# 75.0: 25
# 76.0: 15
# 77.0: 12
# 78.0: 18
# 79.0: 10
# 80.0: 23
# 81.0: 10
# 82.0: 6
# 83.0: 10
# 84.0: 8
# 85.0: 7
# 86.0: 9
# 87.0: 5
# 88.0: 7
# 89.0: 8
# 90.0: 9
# 91.0: 6
# 92.0: 8
# 93.0: 7
# 94.0: 2
# 95.0: 2
# 96.0: 4
# 97.0: 5
# 98.0: 1
# 99.0: 3
# 100.0: 3
# 101.0: 3
# 102.0: 2
# 103.0: 4
# 104.0: 2
# 106.0: 4
# 107.0: 4
# 108.0: 4
# 109.0: 2
# 110.0: 4
# 112.0: 4
# 113.0: 5
# 114.0: 2
# 116.0: 3
# 117.0: 1
# 118.0: 6
# 119.0: 2
# 120.0: 2
# 121.0: 2
# 122.0: 1
# 123.0: 2
# 124.0: 2
# 127.0: 3
# 128.0: 3
# 131.0: 1
# 132.0: 2
# 133.0: 1
# 134.0: 1
# 135.0: 1
# 137.0: 1
# 138.0: 2
# 139.0: 2
# 143.0: 2
# 144.0: 1
# 145.0: 2
# 146.0: 3
# 147.0: 2
# 148.0: 1
# 149.0: 1
# 153.0: 1
# 162.0: 1
# 166.0: 1
# 168.0: 1
# 169.0: 2
# 175.0: 1
# 176.0: 2
# 183.0: 1
# 188.0: 3
# 193.0: 1
# 196.0: 1
# 270.0: 1
# 300.0: 1
# 305.0: 1
# 327.0: 1
# 333.0: 1
# 466.0: 1
# nan: 39

# %%
# Drop rows where 'pageviews' is NaN
df.dropna(subset=['pageviews'], inplace=True)

# Confirm the operation by checking for NaN values again
print(df['pageviews'].isnull().sum())
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193578 entries, 30 to 903645
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   channelGrouping       193578 non-null  object
#  1   date                  193578 non-null  datetime64[ns]
#  2   fullVisitorId         193578 non-null  object
#  3   sessionId             193578 non-null  object
#  4   socialEngagementType  193578 non-null  object
#  5   visitId               193578 non-null  int64
#  6   visitNumber           193578 non-null  int64
#  7   visitStartTime        193578 non-null  int64
#  8   continent             193578 non-null  object
#  9   subContinent          193578 non-null  object
#  10  country               193578 non-null  object
#  11  region                193578 non-null  object
#  12  metro                 193578 non-null  object
#  13  city                  193578 non-null  object
#  14  cityId                193578 non-null  object
#  15  networkDomain         193578 non-null  object
#  16  browser               193578 non-null  object
#  17  operatingSystem       193578 non-null  object
#  18  isMobile              193578 non-null  bool
#  19  deviceCategory        193578 non-null  object
#  20  hits                  193578 non-null  int64
#  21  pageviews             193578 non-null  float64
#  22  bounces               193578 non-null  float64
#  23  newVisits             193578 non-null  float64
#  24  transactionRevenue    193578 non-null  float64
#  25  campaign              193578 non-null  object
#  26  source                193578 non-null  object
#  27  medium                193578 non-null  object
#  28  isTrueDirect          193578 non-null  bool
# dtypes: bool(2), datetime64[ns](1), float64(4), int64(4), object(18)
# memory usage: 41.7+ MB

# %%
df.isnull().sum()
# Out:
# channelGrouping         0
# date                    0
# fullVisitorId           0
# sessionId               0
# socialEngagementType    0
# visitId                 0
# visitNumber             0
# visitStartTime          0
# continent               0
# subContinent            0
# country                 0
# region                  0
# metro                   0
# city                    0
# cityId                  0
# networkDomain           0
# browser                 0
# operatingSystem         0
# isMobile                0
# deviceCategory          0
# hits                    0
# pageviews               0
# bounces                 0
# newVisits               0
# transactionRevenue      0
# campaign                0
# source                  0
# medium                  0
# isTrueDirect            0
# dtype: int64

# %% [markdown]
# #### Creating Conversion Column Preparing the dataset for the classification model [DONT RUN SO ANGEL AND I CAN USE THIS VERSION OF EDA BEFORE SPLITTING FOR USE CASE 1 AND USE CASE 2]

# %%
# Creating a new column 'Conversion' which will be used as the target variable in the classification model. 1 indicates that the customer made a purchase and 0 indicates that the customer did not make a purchase. 
#df['Conversion'] = df['transactionRevenue'].notnull().astype(int)
#df.sample(5)

# %%
# Checking the class distribution of the target variable
#df['Conversion'].value_counts(normalize=True)

# %% [markdown]
# ### Dealing with Useless Variables
#
# Upon inspecting the dataset to determine the useful columns for the use-case and identifying which columns will be dropped, the following observations were made:
#
# - The following columns are IDs and are not useful for modeling but may be needed for eda. Will drop before modeling
#   - `fullVisitorId`
#   - `sessionId`
#   - `visitId`
#   - `cityId`
#
# - The following columns are constant across all observations; therefore, all except `bounces` should be dropped. The `bounces` column contains null values and 1s, indicating that the observations with null values represent users who take actions before exiting:
#   - `socialEngagementType`
#   - `latitude`
#   - `longitude`
#   - `networkLocation`
#   - `browserVersion`
#   - `browserSize`
#   - `operatingSystemVersion`
#   - `mobileDeviceBranding`
#   - `mobileDeviceModel`
#   - `mobileInputSelector`
#   - `mobileDeviceInfo`
#   - `mobileDeviceMarketingName`
#   - `flashVersion`
#   - `language`
#   - `screenColors`
#   - `screenResolution`
#   - `visits`
#   - `newVisits`
#   - `adwordsClickInfo.criteriaParameters`
#   - `isTrueDirect`
#   - `adwordsClickInfo.isVideoAd`
#   - `campaignCode`
# - The `networkDomain` column has too many unique values; therefore, it should be dropped

# %% [markdown]
# ### Handling Missing Values
#
# The following columns have more than 50% missing values, indicating a significant lack of data. To maintain the integrity and effectiveness of our analysis, these columns will be dropped from the dataset:
#
# - `adContent`
# - `adwordsClickInfo.criteriaParameters`
# - `adwordsClickInfo.isVideoAd`
# - `adwordsClickInfo.adNetworkType`
# - `adwordsClickInfo.slot`
# - `adwordsClickInfo.page`
# - `adwordsClickInfo.gclId`
#
# Removing these columns to focus on more complete and informative features for our analysis.
#
# Replacing the null values in the page views column because the instances with NA are the ones with zero page views

# %% [markdown]
# ### Handling the Date Column
# - Split the date column into year, month, and day.
# - Dropped the year as it is not useful for predictive modeling, since past years won't resurface unless we are conducting some temporal analysis.
# - Bucketed the months into first, second, and third quarters.
# - Bucketed the days into beginning, middle, and end of the month.
# - Created a new feature to capture whther a visit was on a weekend or not

# %%
# splitting the date column into year, month and day
df['month']=df['date'].dt.month
df['day']=df['date'].dt.day
df['year']=df['date'].dt.year

# %%
df.head()
# Out:
#     channelGrouping       date        fullVisitorId  \
# 30   Organic Search 2016-09-02   602999120596767867
# 67         Referral 2016-09-02  3746051970600816343
# 117  Organic Search 2016-09-02   504414286758319636
# 142        Referral 2016-09-02  3896314193290395400
# 143  Organic Search 2016-09-02  7370259867769888657
#
#                           sessionId  socialEngagementType     visitId  \
# 30    602999120596767867_1472811390  Not Socially Engaged  1472811390
# 67   3746051970600816343_1472843059  Not Socially Engaged  1472843059
# 117  0504414286758319636_1472812649  Not Socially Engaged  1472812649
# 142  3896314193290395400_1472857005  Not Socially Engaged  1472857005
# 143  7370259867769888657_1472869439  Not Socially Engaged  1472869439
#
#      visitNumber  visitStartTime continent      subContinent  ... bounces  \
# 30             1      1472811390    Europe   Northern Europe  ...     1.0
# 67             2      1472843059  Americas  Northern America  ...     1.0
# 117            1      1472812649  Americas  Northern America  ...     1.0
# 142            2      1472857005  Americas  Northern America  ...     1.0
# 143            2      1472869439  Americas  Northern America  ...     1.0
#
#     newVisits transactionRevenue     campaign               source    medium  \
# 30        1.0                0.0  No Campaign               google   organic
# 67        0.0                0.0  No Campaign     sites.google.com  referral
# 117       1.0                0.0  No Campaign                baidu   organic
# 142       0.0                0.0  No Campaign  mall.googleplex.com  referral
# 143       0.0                0.0  No Campaign                baidu   organic
#
#     isTrueDirect month  day  year
# 30         False     9    2  2016
# 67         False     9    2  2016
# 117        False     9    2  2016
# 142         True     9    2  2016
# 143         True     9    2  2016
#
# [5 rows x 32 columns]

# %%
# bucketing month into quarters
def quarter(x):
    if x in [1,2,3]:
        return '1st_quarter'
    elif x in [4,5,6]:
        return '2nd_quarter'
    elif x in [7,8,9]:
        return '3rd_quarter'
    else:
        return '4th_quarter'
    
df['quarter']=df['month'].apply(quarter)

# %%
# bucking the day column into beginning, middle and end of the month
def day(x):
    if x in range(1,11):
        return 'beginning'
    elif x in range(11,21):
        return 'middle'
    else:
        return 'end'

df['day_of_month']=df['day'].apply(day)

# %%
# Creating a new column 'is_weekend' which will indicate whether the day is a weekday or a weekend
df['is_weekend'] = df['date'].dt.dayofweek.apply(lambda x: 1 if x >= 5 else 0)
df['is_weekend'].value_counts()
# Out:
# 0    168160
# 1     25418
# Name: is_weekend, dtype: int64

# %%
df.head()
# Out:
#     channelGrouping       date        fullVisitorId  \
# 30   Organic Search 2016-09-02   602999120596767867
# 67         Referral 2016-09-02  3746051970600816343
# 117  Organic Search 2016-09-02   504414286758319636
# 142        Referral 2016-09-02  3896314193290395400
# 143  Organic Search 2016-09-02  7370259867769888657
#
#                           sessionId  socialEngagementType     visitId  \
# 30    602999120596767867_1472811390  Not Socially Engaged  1472811390
# 67   3746051970600816343_1472843059  Not Socially Engaged  1472843059
# 117  0504414286758319636_1472812649  Not Socially Engaged  1472812649
# 142  3896314193290395400_1472857005  Not Socially Engaged  1472857005
# 143  7370259867769888657_1472869439  Not Socially Engaged  1472869439
#
#      visitNumber  visitStartTime continent      subContinent  ...  \
# 30             1      1472811390    Europe   Northern Europe  ...
# 67             2      1472843059  Americas  Northern America  ...
# 117            1      1472812649  Americas  Northern America  ...
# 142            2      1472857005  Americas  Northern America  ...
# 143            2      1472869439  Americas  Northern America  ...
#
#         campaign               source    medium isTrueDirect month day  year  \
# 30   No Campaign               google   organic        False     9   2  2016
# 67   No Campaign     sites.google.com  referral        False     9   2  2016
# 117  No Campaign                baidu   organic        False     9   2  2016
# 142  No Campaign  mall.googleplex.com  referral         True     9   2  2016
# 143  No Campaign                baidu   organic         True     9   2  2016
#
#          quarter  day_of_month is_weekend
# 30   3rd_quarter     beginning          0
# 67   3rd_quarter     beginning          0
# 117  3rd_quarter     beginning          0
# 142  3rd_quarter     beginning          0
# 143  3rd_quarter     beginning          0
#
# [5 rows x 35 columns]

# %%
# Chceking the new dimensions of the dataset
df.shape
# Out:
# (193578, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193578 entries, 30 to 903645
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   channelGrouping       193578 non-null  object
#  1   date                  193578 non-null  datetime64[ns]
#  2   fullVisitorId         193578 non-null  object
#  3   sessionId             193578 non-null  object
#  4   socialEngagementType  193578 non-null  object
#  5   visitId               193578 non-null  int64
#  6   visitNumber           193578 non-null  int64
#  7   visitStartTime        193578 non-null  int64
#  8   continent             193578 non-null  object
#  9   subContinent          193578 non-null  object
#  10  country               193578 non-null  object
#  11  region                193578 non-null  object
#  12  metro                 193578 non-null  object
#  13  city                  193578 non-null  object
#  14  cityId                193578 non-null  object
#  15  networkDomain         193578 non-null  object
#  16  browser               193578 non-null  object
#  17  operatingSystem       193578 non-null  object
#  18  isMobile              193578 non-null  bool
#  19  deviceCategory        193578 non-null  object
#  20  hits                  193578 non-null  int64
#  21  pageviews             193578 non-null  float64
#  22  bounces               193578 non-null  float64
#  23  newVisits             193578 non-null  float64
#  24  transactionRevenue    193578 non-null  float64
#  25  campaign              193578 non-null  object
#  26  source                193578 non-null  object
#  27  medium                193578 non-null  object
#  28  isTrueDirect          193578 non-null  bool
#  29  month                 193578 non-null  int64
#  30  day                   193578 non-null  int64
#  31  year                  193578 non-null  int64
#  32  quarter               193578 non-null  object
#  33  day_of_month          193578 non-null  object
#  34  is_weekend            193578 non-null  int64
# dtypes: bool(2), datetime64[ns](1), float64(4), int64(8), object(20)
# memory usage: 50.6+ MB

# %%
df.describe().T
# Out:
#                        count          mean           std           min  \
# visitId             193578.0  1.485823e+09  9.307146e+06  1.470035e+09
# visitNumber         193578.0  3.320073e+00  1.216626e+01  1.000000e+00
# visitStartTime      193578.0  1.485823e+09  9.307146e+06  1.470035e+09
# hits                193578.0  7.049479e+00  1.239374e+01  1.000000e+00
# pageviews           193578.0  5.763790e+00  8.937871e+00  1.000000e+00
# bounces             193578.0  3.254812e-01  4.685556e-01  0.000000e+00
# newVisits           193578.0  6.077085e-01  4.882623e-01  0.000000e+00
# transactionRevenue  193578.0  4.398179e+06  6.679267e+07  0.000000e+00
# month               193578.0  6.797906e+00  3.427319e+00  1.000000e+00
# day                 193578.0  1.563583e+01  8.690189e+00  1.000000e+00
# year                193578.0  2.016559e+03  4.965198e-01  2.016000e+03
# is_weekend          193578.0  1.313062e-01  3.377358e-01  0.000000e+00
#
#                              25%           50%           75%           max
# visitId             1.477891e+09  1.485376e+09  1.494260e+09  1.501657e+09
# visitNumber         1.000000e+00  1.000000e+00  2.000000e+00  3.940000e+02
# visitStartTime      1.477891e+09  1.485376e+09  1.494260e+09  1.501657e+09
# hits                1.000000e+00  3.000000e+00  7.000000e+00  5.000000e+02
# pageviews           1.000000e+00  3.000000e+00  6.000000e+00  4.660000e+02
# bounces             0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# newVisits           0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# transactionRevenue  0.000000e+00  0.000000e+00  0.000000e+00  1.602375e+10
# month               4.000000e+00  7.000000e+00  1.000000e+01  1.200000e+01
# day                 8.000000e+00  1.600000e+01  2.300000e+01  3.100000e+01
# year                2.016000e+03  2.017000e+03  2.017000e+03  2.017000e+03
# is_weekend          0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00

# %% [markdown]
# # Exporting Squeaky Clean Data

# %%
pwd = os.getcwd()
filename = "squeaky_clean_train_data.csv"  # Corrected to include .csv extension
filepath2 = os.path.join(pwd, "Data", filename)

# Save your DataFrame to CSV
df.to_csv(filepath2, index=False)

# %% [markdown]
# ## EDA

# %%
# Convert 'isMobile' to boolean, treating NaN as False
df['isMobile'] = df['isMobile'].fillna(False).astype(bool)

# Verify changes
print(df[['date', 'visitStartTime', 'isMobile', 'pageviews', 'hits']].head())

# Explore distribution of key variables
import matplotlib.pyplot as plt

# Distribution of 'pageviews'
plt.figure(figsize=(10, 6))
plt.hist(df['pageviews'], bins=50, range=[0, 100], color='blue', alpha=0.7)
plt.title('Distribution of Pageviews')
plt.xlabel('Pageviews')
plt.ylabel('Frequency')
plt.show()

# Distribution of 'hits'
plt.figure(figsize=(10, 6))
plt.hist(df['hits'], bins=50, range=[0, 100], color='green', alpha=0.7)
plt.title('Distribution of Hits')
plt.xlabel('Hits')
plt.ylabel('Frequency')
plt.show()

# Analyze visitNumber distribution
plt.figure(figsize=(10, 6))
plt.hist(df['visitNumber'], bins=range(1, 51), color='red', alpha=0.7)
plt.title('Distribution of Visit Number')
plt.xlabel('Visit Number')
plt.ylabel('Frequency')
plt.xlim(0, 50) # Limiting x-axis for better visualization
plt.show()
# Out:
#           date  visitStartTime  isMobile  pageviews  hits
# 30  2016-09-02      1472811390      True        1.0     1
# 67  2016-09-02      1472843059     False        1.0     1
# 117 2016-09-02      1472812649     False        1.0     1
# 142 2016-09-02      1472857005     False        1.0     1
# 143 2016-09-02      1472869439      True        1.0     1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Calculate the mean pageviews and hits by channel grouping
channel_metrics = df.groupby('channelGrouping')['pageviews', 'hits'].mean().reset_index()

# Plot the average pageviews per channel grouping
plt.figure(figsize=(12, 6))
sns.barplot(x='channelGrouping', y='pageviews', data=channel_metrics)
plt.title('Average Pageviews by Channel Grouping')
plt.xticks(rotation=45)
plt.show()

# Plot the average hits per channel grouping
plt.figure(figsize=(12, 6))
sns.barplot(x='channelGrouping', y='hits', data=channel_metrics)
plt.title('Average Hits by Channel Grouping')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/8y/9ttyks_n5f7_6c4hyq6_g50r0000gn/T/ipykernel_10942/3402741400.py:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   channel_metrics = df.groupby('channelGrouping')['pageviews', 'hits'].mean().reset_index()

# %% [markdown]
# #### Observations
# Display: Users coming from display ads are engaging with more pages and generating more hits on average.
#
# Referral: This channel also shows high engagement, which can indicate good quality of traffic coming from these sources.
#
# Social: Traffic from social channels has the lowest engagement in both pageviews and hits, which might suggest that users from social media are less interested or that the content they are presented with is not as relevant.
#
# These insights can be crucial for marketing strategy, as they provide guidance on which channels could be worth investing more into and which might need a reevaluation of strategy.

# %%
# Assuming that a NaN in 'newVisits' means it is not a new visit
df['userType'] = df['newVisits'].apply(lambda x: 'New Visitor' if x == 1.0 else 'Returning Visitor')

# Calculate the mean pageviews and hits by user type
user_type_metrics = df.groupby('userType')['pageviews', 'hits'].mean().reset_index()

# Plot the average pageviews per user type
plt.figure(figsize=(10, 5))
sns.barplot(x='userType', y='pageviews', data=user_type_metrics)
plt.title('Average Pageviews by User Type')
plt.show()

# Plot the average hits per user type
plt.figure(figsize=(10, 5))
sns.barplot(x='userType', y='hits', data=user_type_metrics)
plt.title('Average Hits by User Type')
plt.show()
# Out:
# /var/folders/8y/9ttyks_n5f7_6c4hyq6_g50r0000gn/T/ipykernel_10942/3907542236.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   user_type_metrics = df.groupby('userType')['pageviews', 'hits'].mean().reset_index()

# %% [markdown]
# The plots show a clear pattern: returning visitors tend to view more pages (pageviews) and generate more hits than new visitors.
#
# #### Interpretation
# Higher Engagement: Returning visitors have higher engagement metrics, which could indicate a successful user retention strategy or that once users find the site valuable, they are likely to come back and engage more.
#
# Marketing Strategy: These insights can inform marketing strategies, emphasizing the importance of not just attracting new users but also retaining them, as they are more valuable in terms of engagement.

# %%
# Create a binary column indicating whether there was a transaction
df['had_transaction'] = df['transactionRevenue'].apply(lambda x: 1 if x > 0 else 0)

# Calculate the transaction rate by user type
transaction_rate = df.groupby('userType')['had_transaction'].mean().reset_index()

# Plot the transaction rate per user type
plt.figure(figsize=(10, 5))
sns.barplot(x='userType', y='had_transaction', data=transaction_rate)
plt.title('Transaction Rate by User Type')
plt.show()

# %% [markdown]
# This aligns well with the previous observation that returning visitors are more engaged, as evidenced by higher pageviews and hits. It is reasonable to deduce that higher engagement correlates with a higher likelihood of completing a transaction.
#
# #### Interpretation:
# User Value: Returning visitors not only engage more with the site but are also more likely to contribute to revenue, which makes them a valuable segment of the audience.
#
# Customer Loyalty: The trend suggests a degree of customer loyalty or satisfaction since users are coming back and making purchases.

# %%
# Calculate the average revenue by user type
average_revenue = df.groupby('userType')['transactionRevenue'].mean().reset_index()

# Plot the average revenue per user type
plt.figure(figsize=(10, 5))
sns.barplot(x='userType', y='transactionRevenue', data=average_revenue)
plt.title('Average Revenue by User Type')
plt.show()

# %% [markdown]
# The plot once again reinforces the value of returning visitors, showing that they generate substantially higher average revenue per session compared to new visitors. This suggests that efforts to improve customer retention could be highly beneficial for the business.
#
# #### Interpretation:
# Customer Lifetime Value (CLV): The significant difference in average revenue between new and returning visitors implies that investing in increasing CLV can be a profitable strategy.
#
# Marketing Spend Allocation: It might be advantageous to allocate more budget towards retention strategies or targeted marketing aimed at previous visitors, as they appear to be more lucrative.
